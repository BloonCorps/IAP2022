# %%
import numpy as np
from matplotlib.colors import LogNorm

import matplotlib as mpl
from matplotlib import cm
import matplotlib.pyplot as plt
from matplotlib import colors
from matplotlib.ticker import PercentFormatter

import mdtraj
import math
import simtk.unit as unit
import sys
from sys import exit

import pickle
import argparse
import torch

from iap2022 import utils

# %% [markdown]
# ## Load The Trajectory Files

# %%
traj_list = []

mdtraj.load('traj1.dcd', top='init1.pdb')

topology = mdtraj.load_prmtop()

for idx in range(1):
    traj = mdtraj.load_dcd(f"./data/traj_{idx}.dcd", top = "./data/init1.pdb")
    traj_list.append(traj)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-10-8f0163338e81> in <module>
#       1 traj_list = []
#       2
# ----> 3 mdtraj.load('traj1.dcd', top='init1.pdb')
#       4
#       5 topology = mdtraj.load_prmtop("./data/init1.pdb")
#
# ~/anaconda3/envs/MMCD/lib/python3.8/site-packages/mdtraj/core/trajectory.py in load(filename_or_filenames, discard_overlapping_frames, **kwargs)
#     375         topkwargs.pop("atom_indices", None)
#     376         topkwargs.pop("frame", None)
# --> 377         kwargs["top"] = _parse_topology(kwargs["top"], **topkwargs)
#     378
#     379     # grab the extension of the filename
#
# ~/anaconda3/envs/MMCD/lib/python3.8/site-packages/mdtraj/core/trajectory.py in _parse_topology(top, **kwargs)
#     168
#     169     if isinstance(top, string_types) and (ext in ['.pdb', '.pdb.gz', '.h5','.lh5']):
# --> 170         _traj = load_frame(top, 0, **kwargs)
#     171         topology = _traj.topology
#     172     elif isinstance(top, string_types) and (ext in ['.prmtop', '.parm7', '.prm7']):
#
# ~/anaconda3/envs/MMCD/lib/python3.8/site-packages/mdtraj/core/trajectory.py in load_frame(filename, index, top, atom_indices, **kwargs)
#     308
#     309     if loader.__name__ not in ['load_dtr']:
# --> 310         _assert_files_exist(filename)
#     311     else:
#     312         _assert_files_or_dirs_exist(filename)
#
# ~/anaconda3/envs/MMCD/lib/python3.8/site-packages/mdtraj/core/trajectory.py in _assert_files_exist(filenames)
#      98     for fn in filenames:
#      99         if not (os.path.exists(fn) and os.path.isfile(fn)):
# --> 100             raise IOError('No such file: %s' % fn)
#     101
#     102
#
# OSError: No such file: init1.pdb

# %%
total_traj = mdtraj.join(traj_list[0:625])
psis, phis = [], []

# %%
psis.append(mdtraj.compute_dihedrals(total_traj, [[4, 6, 8, 14]]))
phis.append(mdtraj.compute_dihedrals(total_traj, [[6, 8, 14, 16]]))

# %%
plt.hist(psis[0], bins = 200) 
plt.title("histogram") 
plt.show()

plt.hist(phis[0], bins = 600) 
plt.title("histogram") 
plt.show()

# %%
fig, axs = plt.subplots(1, 2, tight_layout=True)

# N is the count in each bin, bins is the lower-limit of the bin
N, bins, patches = axs[0].hist(psis[0], bins=300)

# We'll color code by height, but you could use any scalar
fracs = N / N.max()

# we need to normalize the data to 0..1 for the full range of the colormap
norm = colors.Normalize(fracs.min(), fracs.max())

# Now, we'll loop through our objects and set the color of each accordingly
for thisfrac, thispatch in zip(fracs, patches):
    color = plt.cm.viridis(norm(thisfrac))
    thispatch.set_facecolor(color)

# We can also normalize our inputs by the total number of counts
axs[1].hist(psis[0], bins=300, density=True)

# Now we format the y-axis to display percentage
axs[1].yaxis.set_major_formatter(PercentFormatter(xmax=1))

# %%
psis = np.reshape(psis, (3125000,))
phis = np.reshape(phis, (3125000,))

# %%
fig, ax = plt.subplots(tight_layout=True)
hist = ax.hist2d(psis, phis, bins = 60)
