# %% [markdown]
# # Contrastive Learning For Normal Distribution

# %% [markdown]
# The normal distribution, for a given mean and variance, specifies the probability density to be:
#
# $$f(x) = \frac{1}{\sigma \sqrt{2 \pi}} \cdot e^{-\frac{1}{2}(\frac{x - \mu}{\sigma})^2}$$
#
# The function is a normalized statistical model, meaning that the probability desnity funcion integrates to $1$ regardless of what values of $\sigma$ and $\pi$ are used. However, suppose instead we now we have
#
# $$f(x) = e^{-\frac{1}{2}(\frac{x - \mu}{\sigma})^2 + c}$$
#
# Now the function no longer itegrates to 1, which poses a problem for MLE estimation of the parameters. Below we use noise contrastive estimation to calculate $\mu, \sigma$, and $c$ for a distribution when we are only given samples of the distribution.

# %%
import matplotlib as mpl
from matplotlib import cm
import matplotlib.pyplot as plt

import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
torch.set_default_dtype(torch.float64)
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib import cm
from sys import exit
import scipy.integrate as integrate
from scipy import optimize


from torch.distributions.normal import Normal
from torch.distributions.uniform import Uniform
from torch.nn import functional as F

# %%
true_dist = Normal(0.7, 1.5)
true_samples = true_dist.sample((100000,))

noise_dist = Normal(-1, 2)
noise_samples = noise_dist.sample((100000,))

# %% [markdown]
# Now we can plot the histograms of the samples to visual the distributions.

# %%
true_samples_np = true_samples.cpu().detach().numpy()
noise_samples_np = noise_samples.cpu().detach().numpy()
plt.hist(true_samples_np, density = True, bins = 100)
plt.show()

# %%
plt.hist(noise_samples_np, density = True, bins = 100)
plt.show()

# %% [markdown]
# ## Learn Constants $\mu, \sigma, c$

# %% [markdown]
# We have a sample of random vectors $x \in \mathbf{R}^d$ which follows an unknown probability density function $p_d(x)$. It is possible to model $p_d(x) = p_m(x; \theta)$ where $\theta$ is a vector of parameters. There exist some parameters $\theta'$ such that $p_d(x) = p_m(x;\theta')$.
#
# However, $\int_{}^{} p_m(x;\theta) dx = 1$.
#
# Even though the contraint can be fufilled in principle by redefining $$p_m(x; \theta) = \frac{p(x;\theta)}{\int_{}^{} p(x;\theta) dx}$$
#
# Here, $\int_{}^{} p(x;\theta) dx$ is called the normalizing constant in statistics or partition function in thermodynamics. In pratice, this integral is rarely tractable.
#
# Noise contrastive estimations defines an estimator that can be estimated by maximizing the objective function. For observed samples $X = (x_1, x_2, ..., x_T)$. We also have $Y = (y_1, y_2, ..., y_T)$ that come from a noise distribution $p_n(x)$. A note below is that we can denote the sigmoid function as $S(x) = \frac{1}{1+e^{-x}}$, such that $h(x; \theta) = S(G(x; \theta))$. Here, the objective function is:
#
# $$J_T(\theta) = \frac{1}{2T} \sum_{t=1}^{T} \ln[ h(x_t; \theta) ] + \ln[1-h(y_t; \theta)] $$
#
# $$h(x; \theta) = \frac{1}{1+e^{-G(x, \theta)}}$$
#
# $$G(x, \theta) = \ln p_m(x; \theta) - \ln p_n(x)$$
#
# Below we can code up all of the functions.

# %%
def ln_p_n(x):
    return noise_dist.log_prob(x)

def ln_p_m(x, theta):
    mu, sigma, c = theta[0], theta[1], theta[2]
    ln_p_m = -(x-mu)**2/(2*sigma**2) + c #Normal(mu, sigma).log_prob(x)
    return ln_p_m #+ 0.5*(np.log(2*np.pi) + np.log(sigma)) - c
    
def G_x_theta(x, theta):
    return ln_p_m(x, theta) - ln_p_n(x)

def h_x_theta(x, theta):
    return torch.sigmoid(G_x_theta(x, theta))

def J_T(theta, X_true, Y_true):
    T = X_true.size()[0] + Y_true.size()[0] 
    J_T = torch.sum(torch.log(h_x_theta(X_true, theta)) + torch.log(1 - h_x_theta(Y_true, theta)))
    return -(1/(2*T))*J_T

#print(J_T([0, 1, 1], true_samples, noise_samples))
#print(J_T([0, 0.5, 1], true_samples, noise_samples))
print(optimize.minimize(J_T, x0=[2, 2, 2], args=(true_samples, noise_samples)))
print(np.log(1/(1.5*np.sqrt(2*np.pi))))
# Out:
#       fun: 0.2888045037974613
#  hess_inv: array([[23.20862469,  4.99597819,  1.47867517],
#        [ 4.99597819,  9.33358149, -5.93482294],
#        [ 1.47867517, -5.93482294, 14.88327564]])
#       jac: array([-1.28895044e-06, -1.31130219e-06, -5.17442822e-06])
#   message: 'Optimization terminated successfully.'
#      nfev: 132
#       nit: 27
#      njev: 33
#    status: 0
#   success: True
#         x: array([ 0.69293571,  1.49816454, -1.32716109])
# -1.324403641312837

# %% [markdown]
# Above, we see that using NCE allows us to properly learn the values of $\mu, \sigma, c$.

# %% [markdown]
# # Learning a General Potential Energy Function

# %% [markdown]
# Above, we defined a normal distribtion to be of the form
#
# $$p(x) = e^{-\frac{(x-\mu)^2}{2\sigma^2}+c}$$
#
# Here, contrastive learning can find the parameters, $\mu, \sigma, c$. However, what if we instead have a neural network parameterise $U_\theta(x)$, such that we have $p(x) = e^{-U_\theta(x)}$?

# %%
class NCE(nn.Module):
    def __init__(self):
        super(NCE, self).__init__()
        self.U_x = nn.Sequential(
          nn.Linear(1, 20),
          nn.Tanh(),
          nn.Linear(20, 100),
          nn.Tanh(),
          nn.Linear(100, 20),
          nn.Tanh(),
          nn.Linear(20, 1),
        )

    def forward(self, x):
        return -self.U_x(x)
        
    def ln_p_m(self, x): #this is U(x)
        return -self.U_x(x)
    
    def ln_p_n(self, x):
        return noise_dist.log_prob(x)
    
    def G_x_theta(self, x):
        return self.ln_p_m(x) - self.ln_p_n(x)

    def h_x_theta(self, x):
        return torch.sigmoid(self.G_x_theta(x))
    
    def loss(self, X_true, Y_true):
        T = X_true.size()[0] + Y_true.size()[0]
        J_T = torch.sum(torch.log(self.h_x_theta(X_true)) + torch.log(1 - self.h_x_theta(Y_true)))
        return -(1/(2*T))*J_T

device = torch.device("cpu")
model = NCE().to(device)
optimizer = optim.Adam(model.parameters(), lr=1e-3)

# %%
def train(epoch, true_samples, noise_samples):
    model.train()
    train_loss = 0

    #true_samples = true_samples.to(device)
    #noise_samples = noise_samples.to(device)

    t = true_dist.sample((1000,1))
    n = noise_dist.sample((1000,1))

    optimizer.zero_grad()
    
    loss = model.loss(t, n)
    loss.backward()

    train_loss += loss.item()
    optimizer.step()

    print(loss)
    
for epoch in range(1, 2000):
    if epoch % 200 == 0:
        print("Epoch", epoch)
    train(epoch, true_samples, noise_samples)
# Out:
# tensor(0.5707, grad_fn=<MulBackward0>)
# tensor(0.5553, grad_fn=<MulBackward0>)
# tensor(0.5388, grad_fn=<MulBackward0>)
# tensor(0.5290, grad_fn=<MulBackward0>)
# tensor(0.5250, grad_fn=<MulBackward0>)
# tensor(0.5066, grad_fn=<MulBackward0>)
# tensor(0.5017, grad_fn=<MulBackward0>)
# tensor(0.4930, grad_fn=<MulBackward0>)
# tensor(0.4748, grad_fn=<MulBackward0>)
# tensor(0.4614, grad_fn=<MulBackward0>)
# tensor(0.4599, grad_fn=<MulBackward0>)
# tensor(0.4430, grad_fn=<MulBackward0>)
# tensor(0.4255, grad_fn=<MulBackward0>)
# tensor(0.4384, grad_fn=<MulBackward0>)
# tensor(0.4208, grad_fn=<MulBackward0>)
# tensor(0.4190, grad_fn=<MulBackward0>)
# tensor(0.4088, grad_fn=<MulBackward0>)
# tensor(0.4109, grad_fn=<MulBackward0>)
# tensor(0.4174, grad_fn=<MulBackward0>)
# tensor(0.4066, grad_fn=<MulBackward0>)
# tensor(0.4141, grad_fn=<MulBackward0>)
# tensor(0.3913, grad_fn=<MulBackward0>)
# tensor(0.3804, grad_fn=<MulBackward0>)
# tensor(0.3866, grad_fn=<MulBackward0>)
# tensor(0.3879, grad_fn=<MulBackward0>)
# tensor(0.3823, grad_fn=<MulBackward0>)
# tensor(0.3931, grad_fn=<MulBackward0>)
# tensor(0.3832, grad_fn=<MulBackward0>)
# tensor(0.3680, grad_fn=<MulBackward0>)
# tensor(0.3634, grad_fn=<MulBackward0>)
# tensor(0.3774, grad_fn=<MulBackward0>)
# tensor(0.3613, grad_fn=<MulBackward0>)
# tensor(0.3707, grad_fn=<MulBackward0>)
# tensor(0.3732, grad_fn=<MulBackward0>)
# tensor(0.3634, grad_fn=<MulBackward0>)
# tensor(0.3600, grad_fn=<MulBackward0>)
# tensor(0.3649, grad_fn=<MulBackward0>)
# tensor(0.3716, grad_fn=<MulBackward0>)
# tensor(0.3754, grad_fn=<MulBackward0>)
# tensor(0.3794, grad_fn=<MulBackward0>)
# tensor(0.3672, grad_fn=<MulBackward0>)
# tensor(0.3737, grad_fn=<MulBackward0>)
# tensor(0.3715, grad_fn=<MulBackward0>)
# tensor(0.3670, grad_fn=<MulBackward0>)
# tensor(0.3534, grad_fn=<MulBackward0>)
# tensor(0.3720, grad_fn=<MulBackward0>)
# tensor(0.3614, grad_fn=<MulBackward0>)
# tensor(0.3630, grad_fn=<MulBackward0>)
# tensor(0.3536, grad_fn=<MulBackward0>)
# tensor(0.3662, grad_fn=<MulBackward0>)
# tensor(0.3656, grad_fn=<MulBackward0>)
# tensor(0.3679, grad_fn=<MulBackward0>)
# tensor(0.3605, grad_fn=<MulBackward0>)
# tensor(0.3678, grad_fn=<MulBackward0>)
# tensor(0.3614, grad_fn=<MulBackward0>)
# tensor(0.3514, grad_fn=<MulBackward0>)
# tensor(0.3525, grad_fn=<MulBackward0>)
# tensor(0.3560, grad_fn=<MulBackward0>)
# tensor(0.3447, grad_fn=<MulBackward0>)
# tensor(0.3627, grad_fn=<MulBackward0>)
# tensor(0.3502, grad_fn=<MulBackward0>)
# tensor(0.3418, grad_fn=<MulBackward0>)
# tensor(0.3540, grad_fn=<MulBackward0>)
# tensor(0.3528, grad_fn=<MulBackward0>)
# tensor(0.3589, grad_fn=<MulBackward0>)
# tensor(0.3495, grad_fn=<MulBackward0>)
# tensor(0.3469, grad_fn=<MulBackward0>)
# tensor(0.3420, grad_fn=<MulBackward0>)
# tensor(0.3547, grad_fn=<MulBackward0>)
# tensor(0.3532, grad_fn=<MulBackward0>)
# tensor(0.3375, grad_fn=<MulBackward0>)
# tensor(0.3450, grad_fn=<MulBackward0>)
# tensor(0.3416, grad_fn=<MulBackward0>)
# tensor(0.3554, grad_fn=<MulBackward0>)
# tensor(0.3421, grad_fn=<MulBackward0>)
# tensor(0.3493, grad_fn=<MulBackward0>)
# tensor(0.3559, grad_fn=<MulBackward0>)
# tensor(0.3393, grad_fn=<MulBackward0>)
# tensor(0.3438, grad_fn=<MulBackward0>)
# tensor(0.3474, grad_fn=<MulBackward0>)
# tensor(0.3420, grad_fn=<MulBackward0>)
# tensor(0.3455, grad_fn=<MulBackward0>)
# tensor(0.3434, grad_fn=<MulBackward0>)
# tensor(0.3447, grad_fn=<MulBackward0>)
# tensor(0.3382, grad_fn=<MulBackward0>)
# tensor(0.3337, grad_fn=<MulBackward0>)
# tensor(0.3465, grad_fn=<MulBackward0>)
# tensor(0.3368, grad_fn=<MulBackward0>)
# tensor(0.3285, grad_fn=<MulBackward0>)
# tensor(0.3358, grad_fn=<MulBackward0>)
# tensor(0.3381, grad_fn=<MulBackward0>)
# tensor(0.3324, grad_fn=<MulBackward0>)
# tensor(0.3232, grad_fn=<MulBackward0>)
# tensor(0.3262, grad_fn=<MulBackward0>)
# tensor(0.3367, grad_fn=<MulBackward0>)
# tensor(0.3293, grad_fn=<MulBackward0>)
# tensor(0.3199, grad_fn=<MulBackward0>)
# tensor(0.3345, grad_fn=<MulBackward0>)
# tensor(0.3305, grad_fn=<MulBackward0>)
# tensor(0.3258, grad_fn=<MulBackward0>)
# tensor(0.3283, grad_fn=<MulBackward0>)
# tensor(0.3231, grad_fn=<MulBackward0>)
# tensor(0.3255, grad_fn=<MulBackward0>)
# tensor(0.3222, grad_fn=<MulBackward0>)
# tensor(0.3278, grad_fn=<MulBackward0>)
# tensor(0.3190, grad_fn=<MulBackward0>)
# tensor(0.3211, grad_fn=<MulBackward0>)
# tensor(0.3270, grad_fn=<MulBackward0>)
# tensor(0.3201, grad_fn=<MulBackward0>)
# tensor(0.3191, grad_fn=<MulBackward0>)
# tensor(0.3213, grad_fn=<MulBackward0>)
# tensor(0.3198, grad_fn=<MulBackward0>)
# tensor(0.3291, grad_fn=<MulBackward0>)
# tensor(0.3185, grad_fn=<MulBackward0>)
# tensor(0.3130, grad_fn=<MulBackward0>)
# tensor(0.3194, grad_fn=<MulBackward0>)
# tensor(0.3142, grad_fn=<MulBackward0>)
# tensor(0.3123, grad_fn=<MulBackward0>)
# tensor(0.3085, grad_fn=<MulBackward0>)
# tensor(0.3059, grad_fn=<MulBackward0>)
# tensor(0.3057, grad_fn=<MulBackward0>)
# tensor(0.3178, grad_fn=<MulBackward0>)
# tensor(0.3212, grad_fn=<MulBackward0>)
# tensor(0.3091, grad_fn=<MulBackward0>)
# tensor(0.3048, grad_fn=<MulBackward0>)
# tensor(0.3079, grad_fn=<MulBackward0>)
# tensor(0.3171, grad_fn=<MulBackward0>)
# tensor(0.3107, grad_fn=<MulBackward0>)
# tensor(0.3164, grad_fn=<MulBackward0>)
# tensor(0.2987, grad_fn=<MulBackward0>)
# tensor(0.3108, grad_fn=<MulBackward0>)
# tensor(0.3111, grad_fn=<MulBackward0>)
# tensor(0.3161, grad_fn=<MulBackward0>)
# tensor(0.3118, grad_fn=<MulBackward0>)
# tensor(0.3093, grad_fn=<MulBackward0>)
# tensor(0.3028, grad_fn=<MulBackward0>)
# tensor(0.3158, grad_fn=<MulBackward0>)
# tensor(0.3146, grad_fn=<MulBackward0>)
# tensor(0.3207, grad_fn=<MulBackward0>)
# tensor(0.3191, grad_fn=<MulBackward0>)
# tensor(0.3142, grad_fn=<MulBackward0>)
# tensor(0.3169, grad_fn=<MulBackward0>)
# tensor(0.3068, grad_fn=<MulBackward0>)
# tensor(0.3075, grad_fn=<MulBackward0>)
# tensor(0.3157, grad_fn=<MulBackward0>)
# tensor(0.3101, grad_fn=<MulBackward0>)
# tensor(0.3130, grad_fn=<MulBackward0>)
# tensor(0.3059, grad_fn=<MulBackward0>)
# tensor(0.3126, grad_fn=<MulBackward0>)
# tensor(0.3091, grad_fn=<MulBackward0>)
# tensor(0.3106, grad_fn=<MulBackward0>)
# tensor(0.3040, grad_fn=<MulBackward0>)
# tensor(0.3071, grad_fn=<MulBackward0>)
# tensor(0.3003, grad_fn=<MulBackward0>)
# tensor(0.3136, grad_fn=<MulBackward0>)
# tensor(0.3136, grad_fn=<MulBackward0>)
# tensor(0.3142, grad_fn=<MulBackward0>)
# tensor(0.3133, grad_fn=<MulBackward0>)
# tensor(0.3194, grad_fn=<MulBackward0>)
# tensor(0.3133, grad_fn=<MulBackward0>)
# tensor(0.3097, grad_fn=<MulBackward0>)
# tensor(0.3039, grad_fn=<MulBackward0>)
# tensor(0.2970, grad_fn=<MulBackward0>)
# tensor(0.3001, grad_fn=<MulBackward0>)
# tensor(0.3087, grad_fn=<MulBackward0>)
# tensor(0.3012, grad_fn=<MulBackward0>)
# tensor(0.3046, grad_fn=<MulBackward0>)
# tensor(0.3005, grad_fn=<MulBackward0>)
# tensor(0.3007, grad_fn=<MulBackward0>)
# tensor(0.3128, grad_fn=<MulBackward0>)
# tensor(0.3140, grad_fn=<MulBackward0>)
# tensor(0.3010, grad_fn=<MulBackward0>)
# tensor(0.2970, grad_fn=<MulBackward0>)
# tensor(0.3069, grad_fn=<MulBackward0>)
# tensor(0.3040, grad_fn=<MulBackward0>)
# tensor(0.3071, grad_fn=<MulBackward0>)
# tensor(0.3017, grad_fn=<MulBackward0>)
# tensor(0.3040, grad_fn=<MulBackward0>)
# tensor(0.3128, grad_fn=<MulBackward0>)
# tensor(0.2991, grad_fn=<MulBackward0>)
# tensor(0.2994, grad_fn=<MulBackward0>)
# tensor(0.3095, grad_fn=<MulBackward0>)
# tensor(0.3053, grad_fn=<MulBackward0>)
# tensor(0.3117, grad_fn=<MulBackward0>)
# tensor(0.3018, grad_fn=<MulBackward0>)
# tensor(0.3059, grad_fn=<MulBackward0>)
# tensor(0.3024, grad_fn=<MulBackward0>)
# tensor(0.2958, grad_fn=<MulBackward0>)
# tensor(0.2942, grad_fn=<MulBackward0>)
# tensor(0.3023, grad_fn=<MulBackward0>)
# tensor(0.3027, grad_fn=<MulBackward0>)
# tensor(0.3053, grad_fn=<MulBackward0>)
# tensor(0.3077, grad_fn=<MulBackward0>)
# tensor(0.3059, grad_fn=<MulBackward0>)
# tensor(0.3053, grad_fn=<MulBackward0>)
# tensor(0.3014, grad_fn=<MulBackward0>)
# tensor(0.3020, grad_fn=<MulBackward0>)
# tensor(0.3075, grad_fn=<MulBackward0>)
# tensor(0.3076, grad_fn=<MulBackward0>)
# Epoch 200
# tensor(0.3072, grad_fn=<MulBackward0>)
# tensor(0.3036, grad_fn=<MulBackward0>)
# tensor(0.3064, grad_fn=<MulBackward0>)
# tensor(0.2903, grad_fn=<MulBackward0>)
# tensor(0.3042, grad_fn=<MulBackward0>)
# tensor(0.2967, grad_fn=<MulBackward0>)
# tensor(0.3038, grad_fn=<MulBackward0>)
# tensor(0.3065, grad_fn=<MulBackward0>)
# tensor(0.3009, grad_fn=<MulBackward0>)
# tensor(0.3031, grad_fn=<MulBackward0>)
# tensor(0.3012, grad_fn=<MulBackward0>)
# tensor(0.2965, grad_fn=<MulBackward0>)
# tensor(0.3036, grad_fn=<MulBackward0>)
# tensor(0.2953, grad_fn=<MulBackward0>)
# tensor(0.3058, grad_fn=<MulBackward0>)
# tensor(0.3048, grad_fn=<MulBackward0>)
# tensor(0.3094, grad_fn=<MulBackward0>)
# tensor(0.3011, grad_fn=<MulBackward0>)
# tensor(0.3025, grad_fn=<MulBackward0>)
# tensor(0.3060, grad_fn=<MulBackward0>)
# tensor(0.3012, grad_fn=<MulBackward0>)
# tensor(0.2980, grad_fn=<MulBackward0>)
# tensor(0.2938, grad_fn=<MulBackward0>)
# tensor(0.2963, grad_fn=<MulBackward0>)
# tensor(0.3035, grad_fn=<MulBackward0>)
# tensor(0.2971, grad_fn=<MulBackward0>)
# tensor(0.2948, grad_fn=<MulBackward0>)
# tensor(0.2968, grad_fn=<MulBackward0>)
# tensor(0.3053, grad_fn=<MulBackward0>)
# tensor(0.2920, grad_fn=<MulBackward0>)
# tensor(0.2988, grad_fn=<MulBackward0>)
# tensor(0.2914, grad_fn=<MulBackward0>)
# tensor(0.2937, grad_fn=<MulBackward0>)
# tensor(0.2963, grad_fn=<MulBackward0>)
# tensor(0.2981, grad_fn=<MulBackward0>)
# tensor(0.2959, grad_fn=<MulBackward0>)
# tensor(0.2995, grad_fn=<MulBackward0>)
# tensor(0.3033, grad_fn=<MulBackward0>)
# tensor(0.2959, grad_fn=<MulBackward0>)
# tensor(0.2971, grad_fn=<MulBackward0>)
# tensor(0.3013, grad_fn=<MulBackward0>)
# tensor(0.2970, grad_fn=<MulBackward0>)
# tensor(0.2889, grad_fn=<MulBackward0>)
# tensor(0.3005, grad_fn=<MulBackward0>)
# tensor(0.2966, grad_fn=<MulBackward0>)
# tensor(0.3054, grad_fn=<MulBackward0>)
# tensor(0.3070, grad_fn=<MulBackward0>)
# tensor(0.2943, grad_fn=<MulBackward0>)
# tensor(0.2943, grad_fn=<MulBackward0>)
# tensor(0.2870, grad_fn=<MulBackward0>)
# tensor(0.3007, grad_fn=<MulBackward0>)
# tensor(0.3007, grad_fn=<MulBackward0>)
# tensor(0.3057, grad_fn=<MulBackward0>)
# tensor(0.3030, grad_fn=<MulBackward0>)
# tensor(0.2909, grad_fn=<MulBackward0>)
# tensor(0.2963, grad_fn=<MulBackward0>)
# tensor(0.2919, grad_fn=<MulBackward0>)
# tensor(0.3009, grad_fn=<MulBackward0>)
# tensor(0.2949, grad_fn=<MulBackward0>)
# tensor(0.2851, grad_fn=<MulBackward0>)
# tensor(0.2975, grad_fn=<MulBackward0>)
# tensor(0.2981, grad_fn=<MulBackward0>)
# tensor(0.3000, grad_fn=<MulBackward0>)
# tensor(0.2977, grad_fn=<MulBackward0>)
# tensor(0.2965, grad_fn=<MulBackward0>)
# tensor(0.2916, grad_fn=<MulBackward0>)
# tensor(0.2917, grad_fn=<MulBackward0>)
# tensor(0.2900, grad_fn=<MulBackward0>)
# tensor(0.3002, grad_fn=<MulBackward0>)
# tensor(0.2895, grad_fn=<MulBackward0>)
# tensor(0.2948, grad_fn=<MulBackward0>)
# tensor(0.2906, grad_fn=<MulBackward0>)
# tensor(0.2981, grad_fn=<MulBackward0>)
# tensor(0.2933, grad_fn=<MulBackward0>)
# tensor(0.2885, grad_fn=<MulBackward0>)
# tensor(0.3028, grad_fn=<MulBackward0>)
# tensor(0.2980, grad_fn=<MulBackward0>)
# tensor(0.2981, grad_fn=<MulBackward0>)
# tensor(0.2951, grad_fn=<MulBackward0>)
# tensor(0.2926, grad_fn=<MulBackward0>)
# tensor(0.2880, grad_fn=<MulBackward0>)
# tensor(0.2964, grad_fn=<MulBackward0>)
# tensor(0.2915, grad_fn=<MulBackward0>)
# tensor(0.3010, grad_fn=<MulBackward0>)
# tensor(0.3017, grad_fn=<MulBackward0>)
# tensor(0.2960, grad_fn=<MulBackward0>)
# tensor(0.2953, grad_fn=<MulBackward0>)
# tensor(0.2916, grad_fn=<MulBackward0>)
# tensor(0.2913, grad_fn=<MulBackward0>)
# tensor(0.3009, grad_fn=<MulBackward0>)
# tensor(0.2925, grad_fn=<MulBackward0>)
# tensor(0.2926, grad_fn=<MulBackward0>)
# tensor(0.3020, grad_fn=<MulBackward0>)
# tensor(0.2950, grad_fn=<MulBackward0>)
# tensor(0.2958, grad_fn=<MulBackward0>)
# tensor(0.2884, grad_fn=<MulBackward0>)
# tensor(0.3008, grad_fn=<MulBackward0>)
# tensor(0.2949, grad_fn=<MulBackward0>)
# tensor(0.2953, grad_fn=<MulBackward0>)
# tensor(0.2976, grad_fn=<MulBackward0>)
# tensor(0.2994, grad_fn=<MulBackward0>)
# tensor(0.2917, grad_fn=<MulBackward0>)
# tensor(0.2924, grad_fn=<MulBackward0>)
# tensor(0.2969, grad_fn=<MulBackward0>)
# tensor(0.2898, grad_fn=<MulBackward0>)
# tensor(0.2952, grad_fn=<MulBackward0>)
# tensor(0.2911, grad_fn=<MulBackward0>)
# tensor(0.2969, grad_fn=<MulBackward0>)
# tensor(0.2877, grad_fn=<MulBackward0>)
# tensor(0.2985, grad_fn=<MulBackward0>)
# tensor(0.2982, grad_fn=<MulBackward0>)
# tensor(0.2876, grad_fn=<MulBackward0>)
# tensor(0.2891, grad_fn=<MulBackward0>)
# tensor(0.2946, grad_fn=<MulBackward0>)
# tensor(0.2856, grad_fn=<MulBackward0>)
# tensor(0.2828, grad_fn=<MulBackward0>)
# tensor(0.2928, grad_fn=<MulBackward0>)
# tensor(0.2914, grad_fn=<MulBackward0>)
# tensor(0.2840, grad_fn=<MulBackward0>)
# tensor(0.2990, grad_fn=<MulBackward0>)
# tensor(0.2998, grad_fn=<MulBackward0>)
# tensor(0.2976, grad_fn=<MulBackward0>)
# tensor(0.3008, grad_fn=<MulBackward0>)
# tensor(0.2911, grad_fn=<MulBackward0>)
# tensor(0.2935, grad_fn=<MulBackward0>)
# tensor(0.2958, grad_fn=<MulBackward0>)
# tensor(0.2929, grad_fn=<MulBackward0>)
# tensor(0.3033, grad_fn=<MulBackward0>)
# tensor(0.2886, grad_fn=<MulBackward0>)
# tensor(0.2911, grad_fn=<MulBackward0>)
# tensor(0.3007, grad_fn=<MulBackward0>)
# tensor(0.2976, grad_fn=<MulBackward0>)
# tensor(0.2949, grad_fn=<MulBackward0>)
# tensor(0.2912, grad_fn=<MulBackward0>)
# tensor(0.2945, grad_fn=<MulBackward0>)
# tensor(0.2977, grad_fn=<MulBackward0>)
# tensor(0.2930, grad_fn=<MulBackward0>)
# tensor(0.2915, grad_fn=<MulBackward0>)
# tensor(0.2971, grad_fn=<MulBackward0>)
# tensor(0.2912, grad_fn=<MulBackward0>)
# tensor(0.2900, grad_fn=<MulBackward0>)
# tensor(0.2951, grad_fn=<MulBackward0>)
# tensor(0.2981, grad_fn=<MulBackward0>)
# tensor(0.2982, grad_fn=<MulBackward0>)
# tensor(0.2936, grad_fn=<MulBackward0>)
# tensor(0.2936, grad_fn=<MulBackward0>)
# tensor(0.2957, grad_fn=<MulBackward0>)
# tensor(0.2935, grad_fn=<MulBackward0>)
# tensor(0.2905, grad_fn=<MulBackward0>)
# tensor(0.2944, grad_fn=<MulBackward0>)
# tensor(0.2914, grad_fn=<MulBackward0>)
# tensor(0.2937, grad_fn=<MulBackward0>)
# tensor(0.2888, grad_fn=<MulBackward0>)
# tensor(0.2918, grad_fn=<MulBackward0>)
# tensor(0.2965, grad_fn=<MulBackward0>)
# tensor(0.2957, grad_fn=<MulBackward0>)
# tensor(0.2988, grad_fn=<MulBackward0>)
# tensor(0.2853, grad_fn=<MulBackward0>)
# tensor(0.2937, grad_fn=<MulBackward0>)
# tensor(0.2907, grad_fn=<MulBackward0>)
# tensor(0.2953, grad_fn=<MulBackward0>)
# tensor(0.2890, grad_fn=<MulBackward0>)
# tensor(0.2888, grad_fn=<MulBackward0>)
# tensor(0.2848, grad_fn=<MulBackward0>)
# tensor(0.2972, grad_fn=<MulBackward0>)
# tensor(0.2998, grad_fn=<MulBackward0>)
# tensor(0.2887, grad_fn=<MulBackward0>)
# tensor(0.2905, grad_fn=<MulBackward0>)
# tensor(0.2950, grad_fn=<MulBackward0>)
# tensor(0.2907, grad_fn=<MulBackward0>)
# tensor(0.2960, grad_fn=<MulBackward0>)
# tensor(0.2954, grad_fn=<MulBackward0>)
# tensor(0.2877, grad_fn=<MulBackward0>)
# tensor(0.2974, grad_fn=<MulBackward0>)
# tensor(0.2901, grad_fn=<MulBackward0>)
# tensor(0.2870, grad_fn=<MulBackward0>)
# tensor(0.2879, grad_fn=<MulBackward0>)
# tensor(0.2910, grad_fn=<MulBackward0>)
# tensor(0.2939, grad_fn=<MulBackward0>)
# tensor(0.2930, grad_fn=<MulBackward0>)
# tensor(0.2885, grad_fn=<MulBackward0>)
# tensor(0.2862, grad_fn=<MulBackward0>)
# tensor(0.2985, grad_fn=<MulBackward0>)
# tensor(0.2860, grad_fn=<MulBackward0>)
# tensor(0.2919, grad_fn=<MulBackward0>)
# tensor(0.3021, grad_fn=<MulBackward0>)
# tensor(0.2983, grad_fn=<MulBackward0>)
# tensor(0.2888, grad_fn=<MulBackward0>)
# tensor(0.2958, grad_fn=<MulBackward0>)
# tensor(0.3002, grad_fn=<MulBackward0>)
# tensor(0.2933, grad_fn=<MulBackward0>)
# tensor(0.2997, grad_fn=<MulBackward0>)
# tensor(0.2913, grad_fn=<MulBackward0>)
# tensor(0.2989, grad_fn=<MulBackward0>)
# tensor(0.2930, grad_fn=<MulBackward0>)
# tensor(0.2938, grad_fn=<MulBackward0>)
# tensor(0.2842, grad_fn=<MulBackward0>)
# tensor(0.2919, grad_fn=<MulBackward0>)
# tensor(0.2893, grad_fn=<MulBackward0>)
# tensor(0.2915, grad_fn=<MulBackward0>)
# Epoch 400
# tensor(0.2890, grad_fn=<MulBackward0>)
# tensor(0.2925, grad_fn=<MulBackward0>)
# tensor(0.2924, grad_fn=<MulBackward0>)
# tensor(0.2922, grad_fn=<MulBackward0>)
# tensor(0.2970, grad_fn=<MulBackward0>)
# tensor(0.2981, grad_fn=<MulBackward0>)
# tensor(0.2935, grad_fn=<MulBackward0>)
# tensor(0.2876, grad_fn=<MulBackward0>)
# tensor(0.2882, grad_fn=<MulBackward0>)
# tensor(0.2943, grad_fn=<MulBackward0>)
# tensor(0.2921, grad_fn=<MulBackward0>)
# tensor(0.2938, grad_fn=<MulBackward0>)
# tensor(0.2913, grad_fn=<MulBackward0>)
# tensor(0.2951, grad_fn=<MulBackward0>)
# tensor(0.3004, grad_fn=<MulBackward0>)
# tensor(0.2946, grad_fn=<MulBackward0>)
# tensor(0.2935, grad_fn=<MulBackward0>)
# tensor(0.2909, grad_fn=<MulBackward0>)
# tensor(0.2885, grad_fn=<MulBackward0>)
# tensor(0.2866, grad_fn=<MulBackward0>)
# tensor(0.2952, grad_fn=<MulBackward0>)
# tensor(0.2965, grad_fn=<MulBackward0>)
# tensor(0.2922, grad_fn=<MulBackward0>)
# tensor(0.2961, grad_fn=<MulBackward0>)
# tensor(0.2859, grad_fn=<MulBackward0>)
# tensor(0.3000, grad_fn=<MulBackward0>)
# tensor(0.2907, grad_fn=<MulBackward0>)
# tensor(0.2958, grad_fn=<MulBackward0>)
# tensor(0.2924, grad_fn=<MulBackward0>)
# tensor(0.2931, grad_fn=<MulBackward0>)
# tensor(0.2881, grad_fn=<MulBackward0>)
# tensor(0.2928, grad_fn=<MulBackward0>)
# tensor(0.2947, grad_fn=<MulBackward0>)
# tensor(0.2933, grad_fn=<MulBackward0>)
# tensor(0.2950, grad_fn=<MulBackward0>)
# tensor(0.2887, grad_fn=<MulBackward0>)
# tensor(0.2917, grad_fn=<MulBackward0>)
# tensor(0.2886, grad_fn=<MulBackward0>)
# tensor(0.2902, grad_fn=<MulBackward0>)
# tensor(0.2878, grad_fn=<MulBackward0>)
# tensor(0.2999, grad_fn=<MulBackward0>)
# tensor(0.2897, grad_fn=<MulBackward0>)
# tensor(0.2920, grad_fn=<MulBackward0>)
# tensor(0.2898, grad_fn=<MulBackward0>)
# tensor(0.2858, grad_fn=<MulBackward0>)
# tensor(0.2953, grad_fn=<MulBackward0>)
# tensor(0.2919, grad_fn=<MulBackward0>)
# tensor(0.2927, grad_fn=<MulBackward0>)
# tensor(0.2854, grad_fn=<MulBackward0>)
# tensor(0.2860, grad_fn=<MulBackward0>)
# tensor(0.2895, grad_fn=<MulBackward0>)
# tensor(0.2858, grad_fn=<MulBackward0>)
# tensor(0.2953, grad_fn=<MulBackward0>)
# tensor(0.2944, grad_fn=<MulBackward0>)
# tensor(0.2918, grad_fn=<MulBackward0>)
# tensor(0.2874, grad_fn=<MulBackward0>)
# tensor(0.2907, grad_fn=<MulBackward0>)
# tensor(0.2912, grad_fn=<MulBackward0>)
# tensor(0.2985, grad_fn=<MulBackward0>)
# tensor(0.2873, grad_fn=<MulBackward0>)
# tensor(0.2859, grad_fn=<MulBackward0>)
# tensor(0.2918, grad_fn=<MulBackward0>)
# tensor(0.2897, grad_fn=<MulBackward0>)
# tensor(0.2941, grad_fn=<MulBackward0>)
# tensor(0.2904, grad_fn=<MulBackward0>)
# tensor(0.2901, grad_fn=<MulBackward0>)
# tensor(0.2955, grad_fn=<MulBackward0>)
# tensor(0.2900, grad_fn=<MulBackward0>)
# tensor(0.2946, grad_fn=<MulBackward0>)
# tensor(0.2866, grad_fn=<MulBackward0>)
# tensor(0.2891, grad_fn=<MulBackward0>)
# tensor(0.2916, grad_fn=<MulBackward0>)
# tensor(0.2893, grad_fn=<MulBackward0>)
# tensor(0.2812, grad_fn=<MulBackward0>)
# tensor(0.2966, grad_fn=<MulBackward0>)
# tensor(0.2922, grad_fn=<MulBackward0>)
# tensor(0.2914, grad_fn=<MulBackward0>)
# tensor(0.2781, grad_fn=<MulBackward0>)
# tensor(0.2886, grad_fn=<MulBackward0>)
# tensor(0.2878, grad_fn=<MulBackward0>)
# tensor(0.2817, grad_fn=<MulBackward0>)
# tensor(0.2959, grad_fn=<MulBackward0>)
# tensor(0.2923, grad_fn=<MulBackward0>)
# tensor(0.2857, grad_fn=<MulBackward0>)
# tensor(0.2944, grad_fn=<MulBackward0>)
# tensor(0.2871, grad_fn=<MulBackward0>)
# tensor(0.2922, grad_fn=<MulBackward0>)
# tensor(0.2873, grad_fn=<MulBackward0>)
# tensor(0.2942, grad_fn=<MulBackward0>)
# tensor(0.2894, grad_fn=<MulBackward0>)
# tensor(0.2947, grad_fn=<MulBackward0>)
# tensor(0.2957, grad_fn=<MulBackward0>)
# tensor(0.2897, grad_fn=<MulBackward0>)
# tensor(0.2864, grad_fn=<MulBackward0>)
# tensor(0.2968, grad_fn=<MulBackward0>)
# tensor(0.2955, grad_fn=<MulBackward0>)
# tensor(0.2868, grad_fn=<MulBackward0>)
# tensor(0.2880, grad_fn=<MulBackward0>)
# tensor(0.2957, grad_fn=<MulBackward0>)
# tensor(0.2950, grad_fn=<MulBackward0>)
# tensor(0.2988, grad_fn=<MulBackward0>)
# tensor(0.2898, grad_fn=<MulBackward0>)
# tensor(0.2929, grad_fn=<MulBackward0>)
# tensor(0.2860, grad_fn=<MulBackward0>)
# tensor(0.2862, grad_fn=<MulBackward0>)
# tensor(0.2906, grad_fn=<MulBackward0>)
# tensor(0.2939, grad_fn=<MulBackward0>)
# tensor(0.2808, grad_fn=<MulBackward0>)
# tensor(0.2941, grad_fn=<MulBackward0>)
# tensor(0.2931, grad_fn=<MulBackward0>)
# tensor(0.2875, grad_fn=<MulBackward0>)
# tensor(0.2985, grad_fn=<MulBackward0>)
# tensor(0.2883, grad_fn=<MulBackward0>)
# tensor(0.2822, grad_fn=<MulBackward0>)
# tensor(0.2908, grad_fn=<MulBackward0>)
# tensor(0.2859, grad_fn=<MulBackward0>)
# tensor(0.2916, grad_fn=<MulBackward0>)
# tensor(0.2881, grad_fn=<MulBackward0>)
# tensor(0.2966, grad_fn=<MulBackward0>)
# tensor(0.2828, grad_fn=<MulBackward0>)
# tensor(0.2924, grad_fn=<MulBackward0>)
# tensor(0.2872, grad_fn=<MulBackward0>)
# tensor(0.2906, grad_fn=<MulBackward0>)
# tensor(0.2939, grad_fn=<MulBackward0>)
# tensor(0.2923, grad_fn=<MulBackward0>)
# tensor(0.2809, grad_fn=<MulBackward0>)
# tensor(0.2946, grad_fn=<MulBackward0>)
# tensor(0.2860, grad_fn=<MulBackward0>)
# tensor(0.2894, grad_fn=<MulBackward0>)
# tensor(0.2880, grad_fn=<MulBackward0>)
# tensor(0.2900, grad_fn=<MulBackward0>)
# tensor(0.2892, grad_fn=<MulBackward0>)
# tensor(0.2909, grad_fn=<MulBackward0>)
# tensor(0.2935, grad_fn=<MulBackward0>)
# tensor(0.2847, grad_fn=<MulBackward0>)
# tensor(0.2929, grad_fn=<MulBackward0>)
# tensor(0.2939, grad_fn=<MulBackward0>)
# tensor(0.2948, grad_fn=<MulBackward0>)
# tensor(0.2830, grad_fn=<MulBackward0>)
# tensor(0.2886, grad_fn=<MulBackward0>)
# tensor(0.2896, grad_fn=<MulBackward0>)
# tensor(0.2898, grad_fn=<MulBackward0>)
# tensor(0.2915, grad_fn=<MulBackward0>)
# tensor(0.2921, grad_fn=<MulBackward0>)
# tensor(0.2926, grad_fn=<MulBackward0>)
# tensor(0.2894, grad_fn=<MulBackward0>)
# tensor(0.2873, grad_fn=<MulBackward0>)
# tensor(0.2904, grad_fn=<MulBackward0>)
# tensor(0.2876, grad_fn=<MulBackward0>)
# tensor(0.2915, grad_fn=<MulBackward0>)
# tensor(0.2903, grad_fn=<MulBackward0>)
# tensor(0.2841, grad_fn=<MulBackward0>)
# tensor(0.2890, grad_fn=<MulBackward0>)
# tensor(0.2841, grad_fn=<MulBackward0>)
# tensor(0.2915, grad_fn=<MulBackward0>)
# tensor(0.2912, grad_fn=<MulBackward0>)
# tensor(0.2930, grad_fn=<MulBackward0>)
# tensor(0.2930, grad_fn=<MulBackward0>)
# tensor(0.2942, grad_fn=<MulBackward0>)
# tensor(0.2914, grad_fn=<MulBackward0>)
# tensor(0.2933, grad_fn=<MulBackward0>)
# tensor(0.2889, grad_fn=<MulBackward0>)
# tensor(0.2873, grad_fn=<MulBackward0>)
# tensor(0.2890, grad_fn=<MulBackward0>)
# tensor(0.2854, grad_fn=<MulBackward0>)
# tensor(0.2921, grad_fn=<MulBackward0>)
# tensor(0.2901, grad_fn=<MulBackward0>)
# tensor(0.3041, grad_fn=<MulBackward0>)
# tensor(0.2828, grad_fn=<MulBackward0>)
# tensor(0.2930, grad_fn=<MulBackward0>)
# tensor(0.2899, grad_fn=<MulBackward0>)
# tensor(0.2906, grad_fn=<MulBackward0>)
# tensor(0.2759, grad_fn=<MulBackward0>)
# tensor(0.2931, grad_fn=<MulBackward0>)
# tensor(0.2924, grad_fn=<MulBackward0>)
# tensor(0.2943, grad_fn=<MulBackward0>)
# tensor(0.2997, grad_fn=<MulBackward0>)
# tensor(0.2961, grad_fn=<MulBackward0>)
# tensor(0.2874, grad_fn=<MulBackward0>)
# tensor(0.2887, grad_fn=<MulBackward0>)
# tensor(0.2935, grad_fn=<MulBackward0>)
# tensor(0.2953, grad_fn=<MulBackward0>)
# tensor(0.2893, grad_fn=<MulBackward0>)
# tensor(0.2898, grad_fn=<MulBackward0>)
# tensor(0.2966, grad_fn=<MulBackward0>)
# tensor(0.2902, grad_fn=<MulBackward0>)
# tensor(0.2955, grad_fn=<MulBackward0>)
# tensor(0.2908, grad_fn=<MulBackward0>)
# tensor(0.2885, grad_fn=<MulBackward0>)
# tensor(0.2877, grad_fn=<MulBackward0>)
# tensor(0.2931, grad_fn=<MulBackward0>)
# tensor(0.2815, grad_fn=<MulBackward0>)
# tensor(0.2896, grad_fn=<MulBackward0>)
# tensor(0.2915, grad_fn=<MulBackward0>)
# tensor(0.2872, grad_fn=<MulBackward0>)
# tensor(0.2916, grad_fn=<MulBackward0>)
# tensor(0.2904, grad_fn=<MulBackward0>)
# tensor(0.2871, grad_fn=<MulBackward0>)
# tensor(0.2905, grad_fn=<MulBackward0>)
# tensor(0.2799, grad_fn=<MulBackward0>)
# Epoch 600
# tensor(0.2849, grad_fn=<MulBackward0>)
# tensor(0.2894, grad_fn=<MulBackward0>)
# tensor(0.2878, grad_fn=<MulBackward0>)
# tensor(0.2838, grad_fn=<MulBackward0>)
# tensor(0.2878, grad_fn=<MulBackward0>)
# tensor(0.2879, grad_fn=<MulBackward0>)
# tensor(0.2956, grad_fn=<MulBackward0>)
# tensor(0.2918, grad_fn=<MulBackward0>)
# tensor(0.2935, grad_fn=<MulBackward0>)
# tensor(0.2919, grad_fn=<MulBackward0>)
# tensor(0.2839, grad_fn=<MulBackward0>)
# tensor(0.2909, grad_fn=<MulBackward0>)
# tensor(0.2855, grad_fn=<MulBackward0>)
# tensor(0.2937, grad_fn=<MulBackward0>)
# tensor(0.2880, grad_fn=<MulBackward0>)
# tensor(0.2891, grad_fn=<MulBackward0>)
# tensor(0.2910, grad_fn=<MulBackward0>)
# tensor(0.2921, grad_fn=<MulBackward0>)
# tensor(0.2822, grad_fn=<MulBackward0>)
# tensor(0.2944, grad_fn=<MulBackward0>)
# tensor(0.2816, grad_fn=<MulBackward0>)
# tensor(0.2921, grad_fn=<MulBackward0>)
# tensor(0.2903, grad_fn=<MulBackward0>)
# tensor(0.2837, grad_fn=<MulBackward0>)
# tensor(0.2988, grad_fn=<MulBackward0>)
# tensor(0.2819, grad_fn=<MulBackward0>)
# tensor(0.2854, grad_fn=<MulBackward0>)
# tensor(0.2850, grad_fn=<MulBackward0>)
# tensor(0.2866, grad_fn=<MulBackward0>)
# tensor(0.2976, grad_fn=<MulBackward0>)
# tensor(0.2879, grad_fn=<MulBackward0>)
# tensor(0.2906, grad_fn=<MulBackward0>)
# tensor(0.2879, grad_fn=<MulBackward0>)
# tensor(0.2944, grad_fn=<MulBackward0>)
# tensor(0.2943, grad_fn=<MulBackward0>)
# tensor(0.2817, grad_fn=<MulBackward0>)
# tensor(0.2819, grad_fn=<MulBackward0>)
# tensor(0.2899, grad_fn=<MulBackward0>)
# tensor(0.2969, grad_fn=<MulBackward0>)
# tensor(0.2947, grad_fn=<MulBackward0>)
# tensor(0.2807, grad_fn=<MulBackward0>)
# tensor(0.2949, grad_fn=<MulBackward0>)
# tensor(0.2914, grad_fn=<MulBackward0>)
# tensor(0.2865, grad_fn=<MulBackward0>)
# tensor(0.2915, grad_fn=<MulBackward0>)
# tensor(0.2922, grad_fn=<MulBackward0>)
# tensor(0.2889, grad_fn=<MulBackward0>)
# tensor(0.2880, grad_fn=<MulBackward0>)
# tensor(0.2864, grad_fn=<MulBackward0>)
# tensor(0.2922, grad_fn=<MulBackward0>)
# tensor(0.2902, grad_fn=<MulBackward0>)
# tensor(0.2983, grad_fn=<MulBackward0>)
# tensor(0.2895, grad_fn=<MulBackward0>)
# tensor(0.2882, grad_fn=<MulBackward0>)
# tensor(0.2976, grad_fn=<MulBackward0>)
# tensor(0.2906, grad_fn=<MulBackward0>)
# tensor(0.2958, grad_fn=<MulBackward0>)
# tensor(0.2944, grad_fn=<MulBackward0>)
# tensor(0.2943, grad_fn=<MulBackward0>)
# tensor(0.2947, grad_fn=<MulBackward0>)
# tensor(0.2841, grad_fn=<MulBackward0>)
# tensor(0.2934, grad_fn=<MulBackward0>)
# tensor(0.2926, grad_fn=<MulBackward0>)
# tensor(0.2896, grad_fn=<MulBackward0>)
# tensor(0.2825, grad_fn=<MulBackward0>)
# tensor(0.2919, grad_fn=<MulBackward0>)
# tensor(0.2945, grad_fn=<MulBackward0>)
# tensor(0.2925, grad_fn=<MulBackward0>)
# tensor(0.2879, grad_fn=<MulBackward0>)
# tensor(0.2921, grad_fn=<MulBackward0>)
# tensor(0.2870, grad_fn=<MulBackward0>)
# tensor(0.2925, grad_fn=<MulBackward0>)
# tensor(0.2841, grad_fn=<MulBackward0>)
# tensor(0.2819, grad_fn=<MulBackward0>)
# tensor(0.2922, grad_fn=<MulBackward0>)
# tensor(0.3012, grad_fn=<MulBackward0>)
# tensor(0.2994, grad_fn=<MulBackward0>)
# tensor(0.2918, grad_fn=<MulBackward0>)
# tensor(0.2918, grad_fn=<MulBackward0>)
# tensor(0.2954, grad_fn=<MulBackward0>)
# tensor(0.3017, grad_fn=<MulBackward0>)
# tensor(0.2823, grad_fn=<MulBackward0>)
# tensor(0.2874, grad_fn=<MulBackward0>)
# tensor(0.2935, grad_fn=<MulBackward0>)
# tensor(0.2935, grad_fn=<MulBackward0>)
# tensor(0.2973, grad_fn=<MulBackward0>)
# tensor(0.2884, grad_fn=<MulBackward0>)
# tensor(0.2835, grad_fn=<MulBackward0>)
# tensor(0.2884, grad_fn=<MulBackward0>)
# tensor(0.2888, grad_fn=<MulBackward0>)
# tensor(0.2885, grad_fn=<MulBackward0>)
# tensor(0.2869, grad_fn=<MulBackward0>)
# tensor(0.2927, grad_fn=<MulBackward0>)
# tensor(0.2779, grad_fn=<MulBackward0>)
# tensor(0.2906, grad_fn=<MulBackward0>)
# tensor(0.2953, grad_fn=<MulBackward0>)
# tensor(0.2891, grad_fn=<MulBackward0>)
# tensor(0.2898, grad_fn=<MulBackward0>)
# tensor(0.3000, grad_fn=<MulBackward0>)
# tensor(0.2826, grad_fn=<MulBackward0>)
# tensor(0.2915, grad_fn=<MulBackward0>)
# tensor(0.2918, grad_fn=<MulBackward0>)
# tensor(0.2911, grad_fn=<MulBackward0>)
# tensor(0.2829, grad_fn=<MulBackward0>)
# tensor(0.2878, grad_fn=<MulBackward0>)
# tensor(0.2856, grad_fn=<MulBackward0>)
# tensor(0.2889, grad_fn=<MulBackward0>)
# tensor(0.2900, grad_fn=<MulBackward0>)
# tensor(0.2847, grad_fn=<MulBackward0>)
# tensor(0.2925, grad_fn=<MulBackward0>)
# tensor(0.2982, grad_fn=<MulBackward0>)
# tensor(0.2906, grad_fn=<MulBackward0>)
# tensor(0.2895, grad_fn=<MulBackward0>)
# tensor(0.2850, grad_fn=<MulBackward0>)
# tensor(0.2960, grad_fn=<MulBackward0>)
# tensor(0.2847, grad_fn=<MulBackward0>)
# tensor(0.2891, grad_fn=<MulBackward0>)
# tensor(0.2930, grad_fn=<MulBackward0>)
# tensor(0.2849, grad_fn=<MulBackward0>)
# tensor(0.2973, grad_fn=<MulBackward0>)
# tensor(0.2930, grad_fn=<MulBackward0>)
# tensor(0.2887, grad_fn=<MulBackward0>)
# tensor(0.2857, grad_fn=<MulBackward0>)
# tensor(0.2880, grad_fn=<MulBackward0>)
# tensor(0.2909, grad_fn=<MulBackward0>)
# tensor(0.2902, grad_fn=<MulBackward0>)
# tensor(0.2945, grad_fn=<MulBackward0>)
# tensor(0.2895, grad_fn=<MulBackward0>)
# tensor(0.2874, grad_fn=<MulBackward0>)
# tensor(0.2897, grad_fn=<MulBackward0>)
# tensor(0.2914, grad_fn=<MulBackward0>)
# tensor(0.2892, grad_fn=<MulBackward0>)
# tensor(0.2901, grad_fn=<MulBackward0>)
# tensor(0.2937, grad_fn=<MulBackward0>)
# tensor(0.2914, grad_fn=<MulBackward0>)
# tensor(0.2900, grad_fn=<MulBackward0>)
# tensor(0.2955, grad_fn=<MulBackward0>)
# tensor(0.2896, grad_fn=<MulBackward0>)
# tensor(0.2943, grad_fn=<MulBackward0>)
# tensor(0.2920, grad_fn=<MulBackward0>)
# tensor(0.2936, grad_fn=<MulBackward0>)
# tensor(0.2869, grad_fn=<MulBackward0>)
# tensor(0.2822, grad_fn=<MulBackward0>)
# tensor(0.2909, grad_fn=<MulBackward0>)
# tensor(0.2972, grad_fn=<MulBackward0>)
# tensor(0.2831, grad_fn=<MulBackward0>)
# tensor(0.2943, grad_fn=<MulBackward0>)
# tensor(0.2879, grad_fn=<MulBackward0>)
# tensor(0.2860, grad_fn=<MulBackward0>)
# tensor(0.2931, grad_fn=<MulBackward0>)
# tensor(0.2897, grad_fn=<MulBackward0>)
# tensor(0.2907, grad_fn=<MulBackward0>)
# tensor(0.2911, grad_fn=<MulBackward0>)
# tensor(0.2946, grad_fn=<MulBackward0>)
# tensor(0.2864, grad_fn=<MulBackward0>)
# tensor(0.2858, grad_fn=<MulBackward0>)
# tensor(0.2893, grad_fn=<MulBackward0>)
# tensor(0.2818, grad_fn=<MulBackward0>)
# tensor(0.2864, grad_fn=<MulBackward0>)
# tensor(0.2950, grad_fn=<MulBackward0>)
# tensor(0.2865, grad_fn=<MulBackward0>)
# tensor(0.2932, grad_fn=<MulBackward0>)
# tensor(0.2927, grad_fn=<MulBackward0>)
# tensor(0.2927, grad_fn=<MulBackward0>)
# tensor(0.2845, grad_fn=<MulBackward0>)
# tensor(0.2880, grad_fn=<MulBackward0>)
# tensor(0.2860, grad_fn=<MulBackward0>)
# tensor(0.2930, grad_fn=<MulBackward0>)
# tensor(0.2905, grad_fn=<MulBackward0>)
# tensor(0.2840, grad_fn=<MulBackward0>)
# tensor(0.2931, grad_fn=<MulBackward0>)
# tensor(0.2844, grad_fn=<MulBackward0>)
# tensor(0.2946, grad_fn=<MulBackward0>)
# tensor(0.2895, grad_fn=<MulBackward0>)
# tensor(0.2886, grad_fn=<MulBackward0>)
# tensor(0.2934, grad_fn=<MulBackward0>)
# tensor(0.2885, grad_fn=<MulBackward0>)
# tensor(0.2865, grad_fn=<MulBackward0>)
# tensor(0.2901, grad_fn=<MulBackward0>)
# tensor(0.2949, grad_fn=<MulBackward0>)
# tensor(0.2880, grad_fn=<MulBackward0>)
# tensor(0.2917, grad_fn=<MulBackward0>)
# tensor(0.2864, grad_fn=<MulBackward0>)
# tensor(0.2894, grad_fn=<MulBackward0>)
# tensor(0.2846, grad_fn=<MulBackward0>)
# tensor(0.2843, grad_fn=<MulBackward0>)
# tensor(0.2969, grad_fn=<MulBackward0>)
# tensor(0.2943, grad_fn=<MulBackward0>)
# tensor(0.2872, grad_fn=<MulBackward0>)
# tensor(0.2901, grad_fn=<MulBackward0>)
# tensor(0.2926, grad_fn=<MulBackward0>)
# tensor(0.2935, grad_fn=<MulBackward0>)
# tensor(0.2875, grad_fn=<MulBackward0>)
# tensor(0.2920, grad_fn=<MulBackward0>)
# tensor(0.2803, grad_fn=<MulBackward0>)
# tensor(0.2904, grad_fn=<MulBackward0>)
# tensor(0.2889, grad_fn=<MulBackward0>)
# tensor(0.2959, grad_fn=<MulBackward0>)
# tensor(0.2958, grad_fn=<MulBackward0>)
# tensor(0.2823, grad_fn=<MulBackward0>)
# Epoch 800
# tensor(0.2913, grad_fn=<MulBackward0>)
# tensor(0.2827, grad_fn=<MulBackward0>)
# tensor(0.2950, grad_fn=<MulBackward0>)
# tensor(0.2918, grad_fn=<MulBackward0>)
# tensor(0.2905, grad_fn=<MulBackward0>)
# tensor(0.2855, grad_fn=<MulBackward0>)
# tensor(0.2953, grad_fn=<MulBackward0>)
# tensor(0.2957, grad_fn=<MulBackward0>)
# tensor(0.2875, grad_fn=<MulBackward0>)
# tensor(0.2871, grad_fn=<MulBackward0>)
# tensor(0.2830, grad_fn=<MulBackward0>)
# tensor(0.2937, grad_fn=<MulBackward0>)
# tensor(0.2989, grad_fn=<MulBackward0>)
# tensor(0.2930, grad_fn=<MulBackward0>)
# tensor(0.2896, grad_fn=<MulBackward0>)
# tensor(0.2859, grad_fn=<MulBackward0>)
# tensor(0.2942, grad_fn=<MulBackward0>)
# tensor(0.2862, grad_fn=<MulBackward0>)
# tensor(0.2909, grad_fn=<MulBackward0>)
# tensor(0.2847, grad_fn=<MulBackward0>)
# tensor(0.2920, grad_fn=<MulBackward0>)
# tensor(0.2839, grad_fn=<MulBackward0>)
# tensor(0.2891, grad_fn=<MulBackward0>)
# tensor(0.2860, grad_fn=<MulBackward0>)
# tensor(0.2897, grad_fn=<MulBackward0>)
# tensor(0.2861, grad_fn=<MulBackward0>)
# tensor(0.2987, grad_fn=<MulBackward0>)
# tensor(0.2832, grad_fn=<MulBackward0>)
# tensor(0.2920, grad_fn=<MulBackward0>)
# tensor(0.2847, grad_fn=<MulBackward0>)
# tensor(0.2934, grad_fn=<MulBackward0>)
# tensor(0.2899, grad_fn=<MulBackward0>)
# tensor(0.2942, grad_fn=<MulBackward0>)
# tensor(0.2851, grad_fn=<MulBackward0>)
# tensor(0.2889, grad_fn=<MulBackward0>)
# tensor(0.2891, grad_fn=<MulBackward0>)
# tensor(0.2862, grad_fn=<MulBackward0>)
# tensor(0.2864, grad_fn=<MulBackward0>)
# tensor(0.2879, grad_fn=<MulBackward0>)
# tensor(0.2893, grad_fn=<MulBackward0>)
# tensor(0.2807, grad_fn=<MulBackward0>)
# tensor(0.2904, grad_fn=<MulBackward0>)
# tensor(0.2877, grad_fn=<MulBackward0>)
# tensor(0.2953, grad_fn=<MulBackward0>)
# tensor(0.2947, grad_fn=<MulBackward0>)
# tensor(0.2941, grad_fn=<MulBackward0>)
# tensor(0.2918, grad_fn=<MulBackward0>)
# tensor(0.2837, grad_fn=<MulBackward0>)
# tensor(0.2861, grad_fn=<MulBackward0>)
# tensor(0.2869, grad_fn=<MulBackward0>)
# tensor(0.2906, grad_fn=<MulBackward0>)
# tensor(0.2893, grad_fn=<MulBackward0>)
# tensor(0.2853, grad_fn=<MulBackward0>)
# tensor(0.2883, grad_fn=<MulBackward0>)
# tensor(0.2874, grad_fn=<MulBackward0>)
# tensor(0.2840, grad_fn=<MulBackward0>)
# tensor(0.2902, grad_fn=<MulBackward0>)
# tensor(0.2855, grad_fn=<MulBackward0>)
# tensor(0.2995, grad_fn=<MulBackward0>)
# tensor(0.2902, grad_fn=<MulBackward0>)
# tensor(0.2931, grad_fn=<MulBackward0>)
# tensor(0.2928, grad_fn=<MulBackward0>)
# tensor(0.2916, grad_fn=<MulBackward0>)
# tensor(0.2835, grad_fn=<MulBackward0>)
# tensor(0.2888, grad_fn=<MulBackward0>)
# tensor(0.2969, grad_fn=<MulBackward0>)
# tensor(0.2811, grad_fn=<MulBackward0>)
# tensor(0.2914, grad_fn=<MulBackward0>)
# tensor(0.2925, grad_fn=<MulBackward0>)
# tensor(0.2916, grad_fn=<MulBackward0>)
# tensor(0.2870, grad_fn=<MulBackward0>)
# tensor(0.2889, grad_fn=<MulBackward0>)
# tensor(0.2898, grad_fn=<MulBackward0>)
# tensor(0.2868, grad_fn=<MulBackward0>)
# tensor(0.2879, grad_fn=<MulBackward0>)
# tensor(0.2859, grad_fn=<MulBackward0>)
# tensor(0.2878, grad_fn=<MulBackward0>)
# tensor(0.2980, grad_fn=<MulBackward0>)
# tensor(0.2875, grad_fn=<MulBackward0>)
# tensor(0.2894, grad_fn=<MulBackward0>)
# tensor(0.2944, grad_fn=<MulBackward0>)
# tensor(0.2868, grad_fn=<MulBackward0>)
# tensor(0.2943, grad_fn=<MulBackward0>)
# tensor(0.2947, grad_fn=<MulBackward0>)
# tensor(0.2891, grad_fn=<MulBackward0>)
# tensor(0.2888, grad_fn=<MulBackward0>)
# tensor(0.2890, grad_fn=<MulBackward0>)
# tensor(0.2822, grad_fn=<MulBackward0>)
# tensor(0.2931, grad_fn=<MulBackward0>)
# tensor(0.2946, grad_fn=<MulBackward0>)
# tensor(0.2868, grad_fn=<MulBackward0>)
# tensor(0.2882, grad_fn=<MulBackward0>)
# tensor(0.2870, grad_fn=<MulBackward0>)
# tensor(0.2904, grad_fn=<MulBackward0>)
# tensor(0.2900, grad_fn=<MulBackward0>)
# tensor(0.2875, grad_fn=<MulBackward0>)
# tensor(0.2947, grad_fn=<MulBackward0>)
# tensor(0.2890, grad_fn=<MulBackward0>)
# tensor(0.2894, grad_fn=<MulBackward0>)
# tensor(0.2857, grad_fn=<MulBackward0>)
# tensor(0.2825, grad_fn=<MulBackward0>)
# tensor(0.2926, grad_fn=<MulBackward0>)
# tensor(0.2916, grad_fn=<MulBackward0>)
# tensor(0.2923, grad_fn=<MulBackward0>)
# tensor(0.2845, grad_fn=<MulBackward0>)
# tensor(0.2928, grad_fn=<MulBackward0>)
# tensor(0.2845, grad_fn=<MulBackward0>)
# tensor(0.2884, grad_fn=<MulBackward0>)
# tensor(0.2936, grad_fn=<MulBackward0>)
# tensor(0.2998, grad_fn=<MulBackward0>)
# tensor(0.2812, grad_fn=<MulBackward0>)
# tensor(0.2874, grad_fn=<MulBackward0>)
# tensor(0.2854, grad_fn=<MulBackward0>)
# tensor(0.2907, grad_fn=<MulBackward0>)
# tensor(0.2747, grad_fn=<MulBackward0>)
# tensor(0.2861, grad_fn=<MulBackward0>)
# tensor(0.2892, grad_fn=<MulBackward0>)
# tensor(0.2853, grad_fn=<MulBackward0>)
# tensor(0.2854, grad_fn=<MulBackward0>)
# tensor(0.2841, grad_fn=<MulBackward0>)
# tensor(0.2920, grad_fn=<MulBackward0>)
# tensor(0.2903, grad_fn=<MulBackward0>)
# tensor(0.2879, grad_fn=<MulBackward0>)
# tensor(0.2875, grad_fn=<MulBackward0>)
# tensor(0.2950, grad_fn=<MulBackward0>)
# tensor(0.2928, grad_fn=<MulBackward0>)
# tensor(0.3027, grad_fn=<MulBackward0>)
# tensor(0.2933, grad_fn=<MulBackward0>)
# tensor(0.2875, grad_fn=<MulBackward0>)
# tensor(0.2922, grad_fn=<MulBackward0>)
# tensor(0.3020, grad_fn=<MulBackward0>)
# tensor(0.2889, grad_fn=<MulBackward0>)
# tensor(0.2841, grad_fn=<MulBackward0>)
# tensor(0.2922, grad_fn=<MulBackward0>)
# tensor(0.2832, grad_fn=<MulBackward0>)
# tensor(0.2863, grad_fn=<MulBackward0>)
# tensor(0.2851, grad_fn=<MulBackward0>)
# tensor(0.2877, grad_fn=<MulBackward0>)
# tensor(0.2886, grad_fn=<MulBackward0>)
# tensor(0.2846, grad_fn=<MulBackward0>)
# tensor(0.2931, grad_fn=<MulBackward0>)
# tensor(0.2820, grad_fn=<MulBackward0>)
# tensor(0.2870, grad_fn=<MulBackward0>)
# tensor(0.2944, grad_fn=<MulBackward0>)
# tensor(0.2853, grad_fn=<MulBackward0>)
# tensor(0.2968, grad_fn=<MulBackward0>)
# tensor(0.2921, grad_fn=<MulBackward0>)
# tensor(0.2848, grad_fn=<MulBackward0>)
# tensor(0.2884, grad_fn=<MulBackward0>)
# tensor(0.2805, grad_fn=<MulBackward0>)
# tensor(0.2931, grad_fn=<MulBackward0>)
# tensor(0.2962, grad_fn=<MulBackward0>)
# tensor(0.2888, grad_fn=<MulBackward0>)
# tensor(0.2882, grad_fn=<MulBackward0>)
# tensor(0.2905, grad_fn=<MulBackward0>)
# tensor(0.2807, grad_fn=<MulBackward0>)
# tensor(0.2922, grad_fn=<MulBackward0>)
# tensor(0.2897, grad_fn=<MulBackward0>)
# tensor(0.2954, grad_fn=<MulBackward0>)
# tensor(0.2855, grad_fn=<MulBackward0>)
# tensor(0.2902, grad_fn=<MulBackward0>)
# tensor(0.2925, grad_fn=<MulBackward0>)
# tensor(0.2843, grad_fn=<MulBackward0>)
# tensor(0.2948, grad_fn=<MulBackward0>)
# tensor(0.2883, grad_fn=<MulBackward0>)
# tensor(0.2916, grad_fn=<MulBackward0>)
# tensor(0.2951, grad_fn=<MulBackward0>)
# tensor(0.2880, grad_fn=<MulBackward0>)
# tensor(0.2849, grad_fn=<MulBackward0>)
# tensor(0.2834, grad_fn=<MulBackward0>)
# tensor(0.2842, grad_fn=<MulBackward0>)
# tensor(0.2942, grad_fn=<MulBackward0>)
# tensor(0.2880, grad_fn=<MulBackward0>)
# tensor(0.2912, grad_fn=<MulBackward0>)
# tensor(0.2815, grad_fn=<MulBackward0>)
# tensor(0.2936, grad_fn=<MulBackward0>)
# tensor(0.2935, grad_fn=<MulBackward0>)
# tensor(0.2892, grad_fn=<MulBackward0>)
# tensor(0.2877, grad_fn=<MulBackward0>)
# tensor(0.2842, grad_fn=<MulBackward0>)
# tensor(0.2931, grad_fn=<MulBackward0>)
# tensor(0.2900, grad_fn=<MulBackward0>)
# tensor(0.2910, grad_fn=<MulBackward0>)
# tensor(0.2864, grad_fn=<MulBackward0>)
# tensor(0.2905, grad_fn=<MulBackward0>)
# tensor(0.2889, grad_fn=<MulBackward0>)
# tensor(0.2871, grad_fn=<MulBackward0>)
# tensor(0.2908, grad_fn=<MulBackward0>)
# tensor(0.2855, grad_fn=<MulBackward0>)
# tensor(0.2857, grad_fn=<MulBackward0>)
# tensor(0.2911, grad_fn=<MulBackward0>)
# tensor(0.2851, grad_fn=<MulBackward0>)
# tensor(0.2815, grad_fn=<MulBackward0>)
# tensor(0.2883, grad_fn=<MulBackward0>)
# tensor(0.2852, grad_fn=<MulBackward0>)
# tensor(0.2843, grad_fn=<MulBackward0>)
# tensor(0.2879, grad_fn=<MulBackward0>)
# tensor(0.2891, grad_fn=<MulBackward0>)
# tensor(0.2841, grad_fn=<MulBackward0>)
# tensor(0.2921, grad_fn=<MulBackward0>)
# Epoch 1000
# tensor(0.2951, grad_fn=<MulBackward0>)
# tensor(0.2907, grad_fn=<MulBackward0>)
# tensor(0.2927, grad_fn=<MulBackward0>)
# tensor(0.2937, grad_fn=<MulBackward0>)
# tensor(0.2832, grad_fn=<MulBackward0>)
# tensor(0.2830, grad_fn=<MulBackward0>)
# tensor(0.2955, grad_fn=<MulBackward0>)
# tensor(0.2836, grad_fn=<MulBackward0>)
# tensor(0.2872, grad_fn=<MulBackward0>)
# tensor(0.2907, grad_fn=<MulBackward0>)
# tensor(0.2857, grad_fn=<MulBackward0>)
# tensor(0.2891, grad_fn=<MulBackward0>)
# tensor(0.2821, grad_fn=<MulBackward0>)
# tensor(0.2826, grad_fn=<MulBackward0>)
# tensor(0.2922, grad_fn=<MulBackward0>)
# tensor(0.2874, grad_fn=<MulBackward0>)
# tensor(0.2838, grad_fn=<MulBackward0>)
# tensor(0.2877, grad_fn=<MulBackward0>)
# tensor(0.2867, grad_fn=<MulBackward0>)
# tensor(0.2881, grad_fn=<MulBackward0>)
# tensor(0.2851, grad_fn=<MulBackward0>)
# tensor(0.2887, grad_fn=<MulBackward0>)
# tensor(0.2891, grad_fn=<MulBackward0>)
# tensor(0.2862, grad_fn=<MulBackward0>)
# tensor(0.2958, grad_fn=<MulBackward0>)
# tensor(0.2894, grad_fn=<MulBackward0>)
# tensor(0.2912, grad_fn=<MulBackward0>)
# tensor(0.2897, grad_fn=<MulBackward0>)
# tensor(0.2876, grad_fn=<MulBackward0>)
# tensor(0.2923, grad_fn=<MulBackward0>)
# tensor(0.2791, grad_fn=<MulBackward0>)
# tensor(0.2954, grad_fn=<MulBackward0>)
# tensor(0.2835, grad_fn=<MulBackward0>)
# tensor(0.2898, grad_fn=<MulBackward0>)
# tensor(0.2856, grad_fn=<MulBackward0>)
# tensor(0.2844, grad_fn=<MulBackward0>)
# tensor(0.2928, grad_fn=<MulBackward0>)
# tensor(0.2852, grad_fn=<MulBackward0>)
# tensor(0.2923, grad_fn=<MulBackward0>)
# tensor(0.2858, grad_fn=<MulBackward0>)
# tensor(0.2908, grad_fn=<MulBackward0>)
# tensor(0.2882, grad_fn=<MulBackward0>)
# tensor(0.2947, grad_fn=<MulBackward0>)
# tensor(0.2893, grad_fn=<MulBackward0>)
# tensor(0.2834, grad_fn=<MulBackward0>)
# tensor(0.2895, grad_fn=<MulBackward0>)
# tensor(0.2893, grad_fn=<MulBackward0>)
# tensor(0.2908, grad_fn=<MulBackward0>)
# tensor(0.2902, grad_fn=<MulBackward0>)
# tensor(0.2951, grad_fn=<MulBackward0>)
# tensor(0.2857, grad_fn=<MulBackward0>)
# tensor(0.2848, grad_fn=<MulBackward0>)
# tensor(0.2860, grad_fn=<MulBackward0>)
# tensor(0.2916, grad_fn=<MulBackward0>)
# tensor(0.2870, grad_fn=<MulBackward0>)
# tensor(0.2935, grad_fn=<MulBackward0>)
# tensor(0.2891, grad_fn=<MulBackward0>)
# tensor(0.2880, grad_fn=<MulBackward0>)
# tensor(0.2896, grad_fn=<MulBackward0>)
# tensor(0.2900, grad_fn=<MulBackward0>)
# tensor(0.2926, grad_fn=<MulBackward0>)
# tensor(0.2799, grad_fn=<MulBackward0>)
# tensor(0.2823, grad_fn=<MulBackward0>)
# tensor(0.2900, grad_fn=<MulBackward0>)
# tensor(0.2809, grad_fn=<MulBackward0>)
# tensor(0.2842, grad_fn=<MulBackward0>)
# tensor(0.2874, grad_fn=<MulBackward0>)
# tensor(0.2924, grad_fn=<MulBackward0>)
# tensor(0.2952, grad_fn=<MulBackward0>)
# tensor(0.2859, grad_fn=<MulBackward0>)
# tensor(0.2825, grad_fn=<MulBackward0>)
# tensor(0.2838, grad_fn=<MulBackward0>)
# tensor(0.2947, grad_fn=<MulBackward0>)
# tensor(0.2807, grad_fn=<MulBackward0>)
# tensor(0.2844, grad_fn=<MulBackward0>)
# tensor(0.2941, grad_fn=<MulBackward0>)
# tensor(0.2907, grad_fn=<MulBackward0>)
# tensor(0.2825, grad_fn=<MulBackward0>)
# tensor(0.2885, grad_fn=<MulBackward0>)
# tensor(0.2863, grad_fn=<MulBackward0>)
# tensor(0.2858, grad_fn=<MulBackward0>)
# tensor(0.2905, grad_fn=<MulBackward0>)
# tensor(0.2838, grad_fn=<MulBackward0>)
# tensor(0.2917, grad_fn=<MulBackward0>)
# tensor(0.2839, grad_fn=<MulBackward0>)
# tensor(0.2968, grad_fn=<MulBackward0>)
# tensor(0.2864, grad_fn=<MulBackward0>)
# tensor(0.2825, grad_fn=<MulBackward0>)
# tensor(0.2949, grad_fn=<MulBackward0>)
# tensor(0.2912, grad_fn=<MulBackward0>)
# tensor(0.2895, grad_fn=<MulBackward0>)
# tensor(0.2932, grad_fn=<MulBackward0>)
# tensor(0.2887, grad_fn=<MulBackward0>)
# tensor(0.2858, grad_fn=<MulBackward0>)
# tensor(0.2909, grad_fn=<MulBackward0>)
# tensor(0.2921, grad_fn=<MulBackward0>)
# tensor(0.2950, grad_fn=<MulBackward0>)
# tensor(0.2882, grad_fn=<MulBackward0>)
# tensor(0.2930, grad_fn=<MulBackward0>)
# tensor(0.2948, grad_fn=<MulBackward0>)
# tensor(0.2841, grad_fn=<MulBackward0>)
# tensor(0.2957, grad_fn=<MulBackward0>)
# tensor(0.2878, grad_fn=<MulBackward0>)
# tensor(0.2987, grad_fn=<MulBackward0>)
# tensor(0.2946, grad_fn=<MulBackward0>)
# tensor(0.2871, grad_fn=<MulBackward0>)
# tensor(0.2865, grad_fn=<MulBackward0>)
# tensor(0.2860, grad_fn=<MulBackward0>)
# tensor(0.2872, grad_fn=<MulBackward0>)
# tensor(0.2890, grad_fn=<MulBackward0>)
# tensor(0.2872, grad_fn=<MulBackward0>)
# tensor(0.2870, grad_fn=<MulBackward0>)
# tensor(0.2905, grad_fn=<MulBackward0>)
# tensor(0.2909, grad_fn=<MulBackward0>)
# tensor(0.2931, grad_fn=<MulBackward0>)
# tensor(0.2878, grad_fn=<MulBackward0>)
# tensor(0.2859, grad_fn=<MulBackward0>)
# tensor(0.2944, grad_fn=<MulBackward0>)
# tensor(0.2892, grad_fn=<MulBackward0>)
# tensor(0.2896, grad_fn=<MulBackward0>)
# tensor(0.2898, grad_fn=<MulBackward0>)
# tensor(0.2972, grad_fn=<MulBackward0>)
# tensor(0.2821, grad_fn=<MulBackward0>)
# tensor(0.2890, grad_fn=<MulBackward0>)
# tensor(0.2955, grad_fn=<MulBackward0>)
# tensor(0.2958, grad_fn=<MulBackward0>)
# tensor(0.2837, grad_fn=<MulBackward0>)
# tensor(0.2937, grad_fn=<MulBackward0>)
# tensor(0.2880, grad_fn=<MulBackward0>)
# tensor(0.2914, grad_fn=<MulBackward0>)
# tensor(0.2866, grad_fn=<MulBackward0>)
# tensor(0.2852, grad_fn=<MulBackward0>)
# tensor(0.2885, grad_fn=<MulBackward0>)
# tensor(0.2900, grad_fn=<MulBackward0>)
# tensor(0.2923, grad_fn=<MulBackward0>)
# tensor(0.2886, grad_fn=<MulBackward0>)
# tensor(0.2895, grad_fn=<MulBackward0>)
# tensor(0.2838, grad_fn=<MulBackward0>)
# tensor(0.2884, grad_fn=<MulBackward0>)
# tensor(0.2866, grad_fn=<MulBackward0>)
# tensor(0.2951, grad_fn=<MulBackward0>)
# tensor(0.2816, grad_fn=<MulBackward0>)
# tensor(0.2925, grad_fn=<MulBackward0>)
# tensor(0.2856, grad_fn=<MulBackward0>)
# tensor(0.2904, grad_fn=<MulBackward0>)
# tensor(0.2866, grad_fn=<MulBackward0>)
# tensor(0.2921, grad_fn=<MulBackward0>)
# tensor(0.2843, grad_fn=<MulBackward0>)
# tensor(0.2967, grad_fn=<MulBackward0>)
# tensor(0.2883, grad_fn=<MulBackward0>)
# tensor(0.2901, grad_fn=<MulBackward0>)
# tensor(0.2851, grad_fn=<MulBackward0>)
# tensor(0.2887, grad_fn=<MulBackward0>)
# tensor(0.2821, grad_fn=<MulBackward0>)
# tensor(0.2967, grad_fn=<MulBackward0>)
# tensor(0.2942, grad_fn=<MulBackward0>)
# tensor(0.2883, grad_fn=<MulBackward0>)
# tensor(0.2898, grad_fn=<MulBackward0>)
# tensor(0.2919, grad_fn=<MulBackward0>)
# tensor(0.2890, grad_fn=<MulBackward0>)
# tensor(0.2937, grad_fn=<MulBackward0>)
# tensor(0.2918, grad_fn=<MulBackward0>)
# tensor(0.2958, grad_fn=<MulBackward0>)
# tensor(0.2871, grad_fn=<MulBackward0>)
# tensor(0.2930, grad_fn=<MulBackward0>)
# tensor(0.2925, grad_fn=<MulBackward0>)
# tensor(0.2932, grad_fn=<MulBackward0>)
# tensor(0.2834, grad_fn=<MulBackward0>)
# tensor(0.2881, grad_fn=<MulBackward0>)
# tensor(0.2929, grad_fn=<MulBackward0>)
# tensor(0.2858, grad_fn=<MulBackward0>)
# tensor(0.2899, grad_fn=<MulBackward0>)
# tensor(0.2844, grad_fn=<MulBackward0>)
# tensor(0.2963, grad_fn=<MulBackward0>)
# tensor(0.2953, grad_fn=<MulBackward0>)
# tensor(0.2876, grad_fn=<MulBackward0>)
# tensor(0.2900, grad_fn=<MulBackward0>)
# tensor(0.2861, grad_fn=<MulBackward0>)
# tensor(0.2882, grad_fn=<MulBackward0>)
# tensor(0.2820, grad_fn=<MulBackward0>)
# tensor(0.2839, grad_fn=<MulBackward0>)
# tensor(0.2874, grad_fn=<MulBackward0>)
# tensor(0.2891, grad_fn=<MulBackward0>)
# tensor(0.2984, grad_fn=<MulBackward0>)
# tensor(0.2856, grad_fn=<MulBackward0>)
# tensor(0.2959, grad_fn=<MulBackward0>)
# tensor(0.2920, grad_fn=<MulBackward0>)
# tensor(0.2837, grad_fn=<MulBackward0>)
# tensor(0.2818, grad_fn=<MulBackward0>)
# tensor(0.2803, grad_fn=<MulBackward0>)
# tensor(0.2911, grad_fn=<MulBackward0>)
# tensor(0.2875, grad_fn=<MulBackward0>)
# tensor(0.2936, grad_fn=<MulBackward0>)
# tensor(0.2896, grad_fn=<MulBackward0>)
# tensor(0.2751, grad_fn=<MulBackward0>)
# tensor(0.2811, grad_fn=<MulBackward0>)
# tensor(0.2882, grad_fn=<MulBackward0>)
# tensor(0.2866, grad_fn=<MulBackward0>)
# tensor(0.2844, grad_fn=<MulBackward0>)
# tensor(0.2912, grad_fn=<MulBackward0>)
# Epoch 1200
# tensor(0.2810, grad_fn=<MulBackward0>)
# tensor(0.2979, grad_fn=<MulBackward0>)
# tensor(0.2898, grad_fn=<MulBackward0>)
# tensor(0.2864, grad_fn=<MulBackward0>)
# tensor(0.2928, grad_fn=<MulBackward0>)
# tensor(0.2825, grad_fn=<MulBackward0>)
# tensor(0.2865, grad_fn=<MulBackward0>)
# tensor(0.2905, grad_fn=<MulBackward0>)
# tensor(0.2829, grad_fn=<MulBackward0>)
# tensor(0.2892, grad_fn=<MulBackward0>)
# tensor(0.2917, grad_fn=<MulBackward0>)
# tensor(0.2915, grad_fn=<MulBackward0>)
# tensor(0.2994, grad_fn=<MulBackward0>)
# tensor(0.2941, grad_fn=<MulBackward0>)
# tensor(0.2915, grad_fn=<MulBackward0>)
# tensor(0.2885, grad_fn=<MulBackward0>)
# tensor(0.2929, grad_fn=<MulBackward0>)
# tensor(0.2891, grad_fn=<MulBackward0>)
# tensor(0.2883, grad_fn=<MulBackward0>)
# tensor(0.2872, grad_fn=<MulBackward0>)
# tensor(0.2920, grad_fn=<MulBackward0>)
# tensor(0.2838, grad_fn=<MulBackward0>)
# tensor(0.2853, grad_fn=<MulBackward0>)
# tensor(0.2891, grad_fn=<MulBackward0>)
# tensor(0.2844, grad_fn=<MulBackward0>)
# tensor(0.2892, grad_fn=<MulBackward0>)
# tensor(0.2950, grad_fn=<MulBackward0>)
# tensor(0.2896, grad_fn=<MulBackward0>)
# tensor(0.2848, grad_fn=<MulBackward0>)
# tensor(0.2851, grad_fn=<MulBackward0>)
# ...
# tensor(0.2968, grad_fn=<MulBackward0>)
# tensor(0.2926, grad_fn=<MulBackward0>)
# tensor(0.2938, grad_fn=<MulBackward0>)
# tensor(0.2906, grad_fn=<MulBackward0>)
# tensor(0.2903, grad_fn=<MulBackward0>)
# tensor(0.2961, grad_fn=<MulBackward0>)
# tensor(0.2921, grad_fn=<MulBackward0>)
# tensor(0.2889, grad_fn=<MulBackward0>)
# tensor(0.2851, grad_fn=<MulBackward0>)
# Epoch 1600
# tensor(0.2884, grad_fn=<MulBackward0>)
# tensor(0.2874, grad_fn=<MulBackward0>)
# tensor(0.2894, grad_fn=<MulBackward0>)
# tensor(0.2883, grad_fn=<MulBackward0>)
# tensor(0.2954, grad_fn=<MulBackward0>)
# tensor(0.2779, grad_fn=<MulBackward0>)
# tensor(0.2913, grad_fn=<MulBackward0>)
# tensor(0.2880, grad_fn=<MulBackward0>)
# tensor(0.2922, grad_fn=<MulBackward0>)
# tensor(0.2920, grad_fn=<MulBackward0>)
# tensor(0.2908, grad_fn=<MulBackward0>)
# tensor(0.2976, grad_fn=<MulBackward0>)
# tensor(0.2835, grad_fn=<MulBackward0>)
# tensor(0.2864, grad_fn=<MulBackward0>)
# tensor(0.2946, grad_fn=<MulBackward0>)
# tensor(0.2958, grad_fn=<MulBackward0>)
# tensor(0.2904, grad_fn=<MulBackward0>)
# tensor(0.2859, grad_fn=<MulBackward0>)
# tensor(0.2937, grad_fn=<MulBackward0>)
# tensor(0.2935, grad_fn=<MulBackward0>)
# tensor(0.2859, grad_fn=<MulBackward0>)
# tensor(0.2922, grad_fn=<MulBackward0>)
# tensor(0.2902, grad_fn=<MulBackward0>)
# tensor(0.2992, grad_fn=<MulBackward0>)
# tensor(0.2963, grad_fn=<MulBackward0>)
# tensor(0.2820, grad_fn=<MulBackward0>)
# tensor(0.2908, grad_fn=<MulBackward0>)
# tensor(0.2884, grad_fn=<MulBackward0>)
# tensor(0.2992, grad_fn=<MulBackward0>)
# tensor(0.2901, grad_fn=<MulBackward0>)
# tensor(0.2857, grad_fn=<MulBackward0>)
# tensor(0.2863, grad_fn=<MulBackward0>)
# tensor(0.2886, grad_fn=<MulBackward0>)
# tensor(0.2861, grad_fn=<MulBackward0>)
# tensor(0.2835, grad_fn=<MulBackward0>)
# tensor(0.2898, grad_fn=<MulBackward0>)
# tensor(0.2886, grad_fn=<MulBackward0>)
# tensor(0.2918, grad_fn=<MulBackward0>)
# tensor(0.2865, grad_fn=<MulBackward0>)
# tensor(0.2901, grad_fn=<MulBackward0>)
# tensor(0.2859, grad_fn=<MulBackward0>)
# tensor(0.2880, grad_fn=<MulBackward0>)
# tensor(0.2822, grad_fn=<MulBackward0>)
# tensor(0.2955, grad_fn=<MulBackward0>)
# tensor(0.2945, grad_fn=<MulBackward0>)
# tensor(0.2868, grad_fn=<MulBackward0>)
# tensor(0.2865, grad_fn=<MulBackward0>)
# tensor(0.2801, grad_fn=<MulBackward0>)
# tensor(0.2879, grad_fn=<MulBackward0>)
# tensor(0.2864, grad_fn=<MulBackward0>)
# tensor(0.2853, grad_fn=<MulBackward0>)
# tensor(0.2866, grad_fn=<MulBackward0>)
# tensor(0.2948, grad_fn=<MulBackward0>)
# tensor(0.2887, grad_fn=<MulBackward0>)
# tensor(0.2882, grad_fn=<MulBackward0>)
# tensor(0.2977, grad_fn=<MulBackward0>)
# tensor(0.2858, grad_fn=<MulBackward0>)
# tensor(0.2888, grad_fn=<MulBackward0>)
# tensor(0.2881, grad_fn=<MulBackward0>)
# tensor(0.2896, grad_fn=<MulBackward0>)
# tensor(0.2916, grad_fn=<MulBackward0>)
# tensor(0.2872, grad_fn=<MulBackward0>)
# tensor(0.2958, grad_fn=<MulBackward0>)
# tensor(0.2882, grad_fn=<MulBackward0>)
# tensor(0.2913, grad_fn=<MulBackward0>)
# tensor(0.2942, grad_fn=<MulBackward0>)
# tensor(0.2872, grad_fn=<MulBackward0>)
# tensor(0.2896, grad_fn=<MulBackward0>)
# tensor(0.2926, grad_fn=<MulBackward0>)
# tensor(0.2922, grad_fn=<MulBackward0>)
# tensor(0.2865, grad_fn=<MulBackward0>)
# tensor(0.2839, grad_fn=<MulBackward0>)
# tensor(0.2972, grad_fn=<MulBackward0>)
# tensor(0.2869, grad_fn=<MulBackward0>)
# tensor(0.2896, grad_fn=<MulBackward0>)
# tensor(0.2883, grad_fn=<MulBackward0>)
# tensor(0.2879, grad_fn=<MulBackward0>)
# tensor(0.2924, grad_fn=<MulBackward0>)
# tensor(0.2925, grad_fn=<MulBackward0>)
# tensor(0.2841, grad_fn=<MulBackward0>)
# tensor(0.2961, grad_fn=<MulBackward0>)
# tensor(0.2836, grad_fn=<MulBackward0>)
# tensor(0.2844, grad_fn=<MulBackward0>)
# tensor(0.2881, grad_fn=<MulBackward0>)
# tensor(0.2836, grad_fn=<MulBackward0>)
# tensor(0.2922, grad_fn=<MulBackward0>)
# tensor(0.2892, grad_fn=<MulBackward0>)
# tensor(0.2832, grad_fn=<MulBackward0>)
# tensor(0.2996, grad_fn=<MulBackward0>)
# tensor(0.2954, grad_fn=<MulBackward0>)
# tensor(0.2835, grad_fn=<MulBackward0>)
# tensor(0.2864, grad_fn=<MulBackward0>)
# tensor(0.2780, grad_fn=<MulBackward0>)
# tensor(0.2962, grad_fn=<MulBackward0>)
# tensor(0.2875, grad_fn=<MulBackward0>)
# tensor(0.2864, grad_fn=<MulBackward0>)
# tensor(0.2878, grad_fn=<MulBackward0>)
# tensor(0.2864, grad_fn=<MulBackward0>)
# tensor(0.2894, grad_fn=<MulBackward0>)
# tensor(0.2823, grad_fn=<MulBackward0>)
# tensor(0.2948, grad_fn=<MulBackward0>)
# tensor(0.2931, grad_fn=<MulBackward0>)
# tensor(0.2938, grad_fn=<MulBackward0>)
# tensor(0.2819, grad_fn=<MulBackward0>)
# tensor(0.2914, grad_fn=<MulBackward0>)
# tensor(0.2901, grad_fn=<MulBackward0>)
# tensor(0.2927, grad_fn=<MulBackward0>)
# tensor(0.2871, grad_fn=<MulBackward0>)
# tensor(0.2873, grad_fn=<MulBackward0>)
# tensor(0.2911, grad_fn=<MulBackward0>)
# tensor(0.2824, grad_fn=<MulBackward0>)
# tensor(0.2875, grad_fn=<MulBackward0>)
# tensor(0.2874, grad_fn=<MulBackward0>)
# tensor(0.2855, grad_fn=<MulBackward0>)
# tensor(0.2863, grad_fn=<MulBackward0>)
# tensor(0.2914, grad_fn=<MulBackward0>)
# tensor(0.2871, grad_fn=<MulBackward0>)
# tensor(0.2903, grad_fn=<MulBackward0>)
# tensor(0.2875, grad_fn=<MulBackward0>)
# tensor(0.2898, grad_fn=<MulBackward0>)
# tensor(0.2876, grad_fn=<MulBackward0>)
# tensor(0.2896, grad_fn=<MulBackward0>)
# tensor(0.2933, grad_fn=<MulBackward0>)
# tensor(0.2983, grad_fn=<MulBackward0>)
# tensor(0.2928, grad_fn=<MulBackward0>)
# tensor(0.2850, grad_fn=<MulBackward0>)
# tensor(0.2855, grad_fn=<MulBackward0>)
# tensor(0.2869, grad_fn=<MulBackward0>)
# tensor(0.2929, grad_fn=<MulBackward0>)
# tensor(0.2826, grad_fn=<MulBackward0>)
# tensor(0.2884, grad_fn=<MulBackward0>)
# tensor(0.2847, grad_fn=<MulBackward0>)
# tensor(0.2902, grad_fn=<MulBackward0>)
# tensor(0.2775, grad_fn=<MulBackward0>)
# tensor(0.2860, grad_fn=<MulBackward0>)
# tensor(0.2927, grad_fn=<MulBackward0>)
# tensor(0.2874, grad_fn=<MulBackward0>)
# tensor(0.2903, grad_fn=<MulBackward0>)
# tensor(0.2879, grad_fn=<MulBackward0>)
# tensor(0.2843, grad_fn=<MulBackward0>)
# tensor(0.2976, grad_fn=<MulBackward0>)
# tensor(0.2827, grad_fn=<MulBackward0>)
# tensor(0.2861, grad_fn=<MulBackward0>)
# tensor(0.2945, grad_fn=<MulBackward0>)
# tensor(0.2883, grad_fn=<MulBackward0>)
# tensor(0.2916, grad_fn=<MulBackward0>)
# tensor(0.2897, grad_fn=<MulBackward0>)
# tensor(0.2938, grad_fn=<MulBackward0>)
# tensor(0.2870, grad_fn=<MulBackward0>)
# tensor(0.2790, grad_fn=<MulBackward0>)
# tensor(0.2888, grad_fn=<MulBackward0>)
# tensor(0.2877, grad_fn=<MulBackward0>)
# tensor(0.2866, grad_fn=<MulBackward0>)
# tensor(0.2905, grad_fn=<MulBackward0>)
# tensor(0.2828, grad_fn=<MulBackward0>)
# tensor(0.2910, grad_fn=<MulBackward0>)
# tensor(0.2832, grad_fn=<MulBackward0>)
# tensor(0.2839, grad_fn=<MulBackward0>)
# tensor(0.2903, grad_fn=<MulBackward0>)
# tensor(0.2879, grad_fn=<MulBackward0>)
# tensor(0.2906, grad_fn=<MulBackward0>)
# tensor(0.2879, grad_fn=<MulBackward0>)
# tensor(0.2920, grad_fn=<MulBackward0>)
# tensor(0.2937, grad_fn=<MulBackward0>)
# tensor(0.2777, grad_fn=<MulBackward0>)
# tensor(0.2895, grad_fn=<MulBackward0>)
# tensor(0.2915, grad_fn=<MulBackward0>)
# tensor(0.2936, grad_fn=<MulBackward0>)
# tensor(0.2829, grad_fn=<MulBackward0>)
# tensor(0.2906, grad_fn=<MulBackward0>)
# tensor(0.2935, grad_fn=<MulBackward0>)
# tensor(0.2888, grad_fn=<MulBackward0>)
# tensor(0.2900, grad_fn=<MulBackward0>)
# tensor(0.2839, grad_fn=<MulBackward0>)
# tensor(0.2941, grad_fn=<MulBackward0>)
# tensor(0.2847, grad_fn=<MulBackward0>)
# tensor(0.2957, grad_fn=<MulBackward0>)
# tensor(0.2893, grad_fn=<MulBackward0>)
# tensor(0.2932, grad_fn=<MulBackward0>)
# tensor(0.2943, grad_fn=<MulBackward0>)
# tensor(0.2976, grad_fn=<MulBackward0>)
# tensor(0.2922, grad_fn=<MulBackward0>)
# tensor(0.2962, grad_fn=<MulBackward0>)
# tensor(0.2868, grad_fn=<MulBackward0>)
# tensor(0.2865, grad_fn=<MulBackward0>)
# tensor(0.2928, grad_fn=<MulBackward0>)
# tensor(0.2845, grad_fn=<MulBackward0>)
# tensor(0.2953, grad_fn=<MulBackward0>)
# tensor(0.2881, grad_fn=<MulBackward0>)
# tensor(0.2916, grad_fn=<MulBackward0>)
# tensor(0.2880, grad_fn=<MulBackward0>)
# tensor(0.2848, grad_fn=<MulBackward0>)
# tensor(0.2883, grad_fn=<MulBackward0>)
# tensor(0.2897, grad_fn=<MulBackward0>)
# tensor(0.2903, grad_fn=<MulBackward0>)
# tensor(0.2854, grad_fn=<MulBackward0>)
# tensor(0.2946, grad_fn=<MulBackward0>)
# tensor(0.2869, grad_fn=<MulBackward0>)
# tensor(0.2841, grad_fn=<MulBackward0>)
# tensor(0.2883, grad_fn=<MulBackward0>)
# Epoch 1800
# tensor(0.2836, grad_fn=<MulBackward0>)
# tensor(0.2888, grad_fn=<MulBackward0>)
# tensor(0.2896, grad_fn=<MulBackward0>)
# tensor(0.2914, grad_fn=<MulBackward0>)
# tensor(0.2812, grad_fn=<MulBackward0>)
# tensor(0.2893, grad_fn=<MulBackward0>)
# tensor(0.2864, grad_fn=<MulBackward0>)
# tensor(0.2766, grad_fn=<MulBackward0>)
# tensor(0.2844, grad_fn=<MulBackward0>)
# tensor(0.2915, grad_fn=<MulBackward0>)
# tensor(0.2869, grad_fn=<MulBackward0>)
# tensor(0.2915, grad_fn=<MulBackward0>)
# tensor(0.2964, grad_fn=<MulBackward0>)
# tensor(0.2863, grad_fn=<MulBackward0>)
# tensor(0.2912, grad_fn=<MulBackward0>)
# tensor(0.2777, grad_fn=<MulBackward0>)
# tensor(0.2926, grad_fn=<MulBackward0>)
# tensor(0.2845, grad_fn=<MulBackward0>)
# tensor(0.2935, grad_fn=<MulBackward0>)
# tensor(0.2934, grad_fn=<MulBackward0>)
# tensor(0.2908, grad_fn=<MulBackward0>)
# tensor(0.2849, grad_fn=<MulBackward0>)
# tensor(0.2871, grad_fn=<MulBackward0>)
# tensor(0.2946, grad_fn=<MulBackward0>)
# tensor(0.2908, grad_fn=<MulBackward0>)
# tensor(0.2905, grad_fn=<MulBackward0>)
# tensor(0.2892, grad_fn=<MulBackward0>)
# tensor(0.2880, grad_fn=<MulBackward0>)
# tensor(0.2856, grad_fn=<MulBackward0>)
# tensor(0.2857, grad_fn=<MulBackward0>)
# tensor(0.2825, grad_fn=<MulBackward0>)
# tensor(0.2820, grad_fn=<MulBackward0>)
# tensor(0.2942, grad_fn=<MulBackward0>)
# tensor(0.2851, grad_fn=<MulBackward0>)
# tensor(0.2893, grad_fn=<MulBackward0>)
# tensor(0.2851, grad_fn=<MulBackward0>)
# tensor(0.2860, grad_fn=<MulBackward0>)
# tensor(0.2899, grad_fn=<MulBackward0>)
# tensor(0.2833, grad_fn=<MulBackward0>)
# tensor(0.2859, grad_fn=<MulBackward0>)
# tensor(0.2967, grad_fn=<MulBackward0>)
# tensor(0.2925, grad_fn=<MulBackward0>)
# tensor(0.3000, grad_fn=<MulBackward0>)
# tensor(0.2865, grad_fn=<MulBackward0>)
# tensor(0.2933, grad_fn=<MulBackward0>)
# tensor(0.2930, grad_fn=<MulBackward0>)
# tensor(0.2821, grad_fn=<MulBackward0>)
# tensor(0.2846, grad_fn=<MulBackward0>)
# tensor(0.2820, grad_fn=<MulBackward0>)
# tensor(0.2921, grad_fn=<MulBackward0>)
# tensor(0.2951, grad_fn=<MulBackward0>)
# tensor(0.2926, grad_fn=<MulBackward0>)
# tensor(0.2920, grad_fn=<MulBackward0>)
# tensor(0.2817, grad_fn=<MulBackward0>)
# tensor(0.2959, grad_fn=<MulBackward0>)
# tensor(0.2878, grad_fn=<MulBackward0>)
# tensor(0.2923, grad_fn=<MulBackward0>)
# tensor(0.2844, grad_fn=<MulBackward0>)
# tensor(0.2830, grad_fn=<MulBackward0>)
# tensor(0.2902, grad_fn=<MulBackward0>)
# tensor(0.2807, grad_fn=<MulBackward0>)
# tensor(0.2934, grad_fn=<MulBackward0>)
# tensor(0.2909, grad_fn=<MulBackward0>)
# tensor(0.2777, grad_fn=<MulBackward0>)
# tensor(0.2936, grad_fn=<MulBackward0>)
# tensor(0.2862, grad_fn=<MulBackward0>)
# tensor(0.2919, grad_fn=<MulBackward0>)
# tensor(0.2952, grad_fn=<MulBackward0>)
# tensor(0.2826, grad_fn=<MulBackward0>)
# tensor(0.2881, grad_fn=<MulBackward0>)
# tensor(0.2908, grad_fn=<MulBackward0>)
# tensor(0.2827, grad_fn=<MulBackward0>)
# tensor(0.2897, grad_fn=<MulBackward0>)
# tensor(0.2892, grad_fn=<MulBackward0>)
# tensor(0.2934, grad_fn=<MulBackward0>)
# tensor(0.2906, grad_fn=<MulBackward0>)
# tensor(0.2836, grad_fn=<MulBackward0>)
# tensor(0.2906, grad_fn=<MulBackward0>)
# tensor(0.2874, grad_fn=<MulBackward0>)
# tensor(0.2974, grad_fn=<MulBackward0>)
# tensor(0.2886, grad_fn=<MulBackward0>)
# tensor(0.2891, grad_fn=<MulBackward0>)
# tensor(0.2895, grad_fn=<MulBackward0>)
# tensor(0.2956, grad_fn=<MulBackward0>)
# tensor(0.2910, grad_fn=<MulBackward0>)
# tensor(0.2922, grad_fn=<MulBackward0>)
# tensor(0.2903, grad_fn=<MulBackward0>)
# tensor(0.2918, grad_fn=<MulBackward0>)
# tensor(0.2830, grad_fn=<MulBackward0>)
# tensor(0.2911, grad_fn=<MulBackward0>)
# tensor(0.2852, grad_fn=<MulBackward0>)
# tensor(0.2835, grad_fn=<MulBackward0>)
# tensor(0.2940, grad_fn=<MulBackward0>)
# tensor(0.2946, grad_fn=<MulBackward0>)
# tensor(0.2862, grad_fn=<MulBackward0>)
# tensor(0.2814, grad_fn=<MulBackward0>)
# tensor(0.2768, grad_fn=<MulBackward0>)
# tensor(0.2894, grad_fn=<MulBackward0>)
# tensor(0.2953, grad_fn=<MulBackward0>)
# tensor(0.2833, grad_fn=<MulBackward0>)
# tensor(0.2924, grad_fn=<MulBackward0>)
# tensor(0.2896, grad_fn=<MulBackward0>)
# tensor(0.2881, grad_fn=<MulBackward0>)
# tensor(0.2920, grad_fn=<MulBackward0>)
# tensor(0.2843, grad_fn=<MulBackward0>)
# tensor(0.2953, grad_fn=<MulBackward0>)
# tensor(0.2902, grad_fn=<MulBackward0>)
# tensor(0.2840, grad_fn=<MulBackward0>)
# tensor(0.2859, grad_fn=<MulBackward0>)
# tensor(0.2873, grad_fn=<MulBackward0>)
# tensor(0.2897, grad_fn=<MulBackward0>)
# tensor(0.2934, grad_fn=<MulBackward0>)
# tensor(0.3002, grad_fn=<MulBackward0>)
# tensor(0.2796, grad_fn=<MulBackward0>)
# tensor(0.2919, grad_fn=<MulBackward0>)
# tensor(0.2899, grad_fn=<MulBackward0>)
# tensor(0.2874, grad_fn=<MulBackward0>)
# tensor(0.2771, grad_fn=<MulBackward0>)
# tensor(0.2848, grad_fn=<MulBackward0>)
# tensor(0.2870, grad_fn=<MulBackward0>)
# tensor(0.2863, grad_fn=<MulBackward0>)
# tensor(0.2941, grad_fn=<MulBackward0>)
# tensor(0.2859, grad_fn=<MulBackward0>)
# tensor(0.2790, grad_fn=<MulBackward0>)
# tensor(0.2888, grad_fn=<MulBackward0>)
# tensor(0.2884, grad_fn=<MulBackward0>)
# tensor(0.2823, grad_fn=<MulBackward0>)
# tensor(0.2847, grad_fn=<MulBackward0>)
# tensor(0.2922, grad_fn=<MulBackward0>)
# tensor(0.2858, grad_fn=<MulBackward0>)
# tensor(0.2933, grad_fn=<MulBackward0>)
# tensor(0.2945, grad_fn=<MulBackward0>)
# tensor(0.2878, grad_fn=<MulBackward0>)
# tensor(0.2843, grad_fn=<MulBackward0>)
# tensor(0.2851, grad_fn=<MulBackward0>)
# tensor(0.2864, grad_fn=<MulBackward0>)
# tensor(0.2841, grad_fn=<MulBackward0>)
# tensor(0.2867, grad_fn=<MulBackward0>)
# tensor(0.2934, grad_fn=<MulBackward0>)
# tensor(0.2879, grad_fn=<MulBackward0>)
# tensor(0.3039, grad_fn=<MulBackward0>)
# tensor(0.2914, grad_fn=<MulBackward0>)
# tensor(0.2915, grad_fn=<MulBackward0>)
# tensor(0.2877, grad_fn=<MulBackward0>)
# tensor(0.2831, grad_fn=<MulBackward0>)
# tensor(0.2931, grad_fn=<MulBackward0>)
# tensor(0.2930, grad_fn=<MulBackward0>)
# tensor(0.2840, grad_fn=<MulBackward0>)
# tensor(0.2820, grad_fn=<MulBackward0>)
# tensor(0.2914, grad_fn=<MulBackward0>)
# tensor(0.3027, grad_fn=<MulBackward0>)
# tensor(0.2930, grad_fn=<MulBackward0>)
# tensor(0.2918, grad_fn=<MulBackward0>)
# tensor(0.2869, grad_fn=<MulBackward0>)
# tensor(0.2912, grad_fn=<MulBackward0>)
# tensor(0.2845, grad_fn=<MulBackward0>)
# tensor(0.2975, grad_fn=<MulBackward0>)
# tensor(0.2913, grad_fn=<MulBackward0>)
# tensor(0.2888, grad_fn=<MulBackward0>)
# tensor(0.2878, grad_fn=<MulBackward0>)
# tensor(0.2890, grad_fn=<MulBackward0>)
# tensor(0.2957, grad_fn=<MulBackward0>)
# tensor(0.2958, grad_fn=<MulBackward0>)
# tensor(0.2920, grad_fn=<MulBackward0>)
# tensor(0.2862, grad_fn=<MulBackward0>)
# tensor(0.2847, grad_fn=<MulBackward0>)
# tensor(0.2815, grad_fn=<MulBackward0>)
# tensor(0.2874, grad_fn=<MulBackward0>)
# tensor(0.2822, grad_fn=<MulBackward0>)
# tensor(0.2883, grad_fn=<MulBackward0>)
# tensor(0.2892, grad_fn=<MulBackward0>)
# tensor(0.2884, grad_fn=<MulBackward0>)
# tensor(0.2922, grad_fn=<MulBackward0>)
# tensor(0.2888, grad_fn=<MulBackward0>)
# tensor(0.2927, grad_fn=<MulBackward0>)
# tensor(0.2874, grad_fn=<MulBackward0>)
# tensor(0.2883, grad_fn=<MulBackward0>)
# tensor(0.2971, grad_fn=<MulBackward0>)
# tensor(0.2899, grad_fn=<MulBackward0>)
# tensor(0.2842, grad_fn=<MulBackward0>)
# tensor(0.2918, grad_fn=<MulBackward0>)
# tensor(0.2924, grad_fn=<MulBackward0>)
# tensor(0.2896, grad_fn=<MulBackward0>)
# tensor(0.2930, grad_fn=<MulBackward0>)
# tensor(0.2850, grad_fn=<MulBackward0>)
# tensor(0.2901, grad_fn=<MulBackward0>)
# tensor(0.2894, grad_fn=<MulBackward0>)
# tensor(0.2975, grad_fn=<MulBackward0>)
# tensor(0.2888, grad_fn=<MulBackward0>)
# tensor(0.2832, grad_fn=<MulBackward0>)
# tensor(0.2883, grad_fn=<MulBackward0>)
# tensor(0.2856, grad_fn=<MulBackward0>)
# tensor(0.2928, grad_fn=<MulBackward0>)
# tensor(0.2949, grad_fn=<MulBackward0>)
# tensor(0.2937, grad_fn=<MulBackward0>)
# tensor(0.2927, grad_fn=<MulBackward0>)
# tensor(0.2959, grad_fn=<MulBackward0>)
# tensor(0.2924, grad_fn=<MulBackward0>)
# tensor(0.2854, grad_fn=<MulBackward0>)
# tensor(0.2900, grad_fn=<MulBackward0>)

# %%
def true_U_x(x, mu, sigma, c):
    return (-(x-mu)**2)/(2*sigma**2) + c
    
lines = np.linspace(-3.3, 4.7, 1000)
mu = 0.7
sigma = 1.5
c = -1.324403641312837

U_x_curve_true = [true_U_x(l, mu, sigma, c) for l in lines]
U_x_curve = [(model(torch.tensor(l).reshape(1,1))).detach().numpy()[0][0] for l in lines]

plt.plot(lines, U_x_curve_true)
plt.plot(lines, U_x_curve)

# %%
def U_learned_x(x):
    return np.exp((model(torch.tensor(x).reshape(1,1).to(device))).cpu().detach().numpy()[0][0])

integrate.quad(U_learned_x, -4, 4)[0]
# Out:
# 1.0260600824789177
